# %% [markdown]
# load the url list

# %%
import json

# open up the url_list
with open(
    "C:/python-projects/zillow_webscraper/issues/zillow-webscraper/data/raw_v2/url_exts_2.json",
    "r",
) as f:
    raw_url_ext_list = f.read()

url_ext_list = json.loads(raw_url_ext_list)

# **FIX PLS repeats in the urls probably from the problems in the rent interval ;.; going to fix later
# url_ext_list = url_ext_list[0:540]

# %% [markdown]
# get's the building key from the url extensions and store it in a new param_list

# %%
# List of rotating proxies
proxies_list = [
    {"socks5": "72.210.221.197:4145"},
    {"socks5": "199.229.254.129:4145"},
    {"socks5": "74.119.147.209:4145"},
    {"socks5": "68.1.210.163:4145"},
    {"socks5": "184.178.172.17:4145"},
    {"socks5": "142.54.228.193:4145"},
    {"socks5": "70.166.167.55:57745"},
    {"socks5": "184.181.217.201:4145"},
    {"socks5": "107.152.98.5:4145"},
    {"socks5": "72.221.171.130:4145"},
    {"socks5": "98.181.137.83:4145"},
    {"socks5": "142.54.237.34:4145"},
    {"socks5": "184.170.248.5:4145"},
    {"socks5": "72.210.221.197:4145"},
    {"socks5": "192.252.208.67:14287"},
    {"socks5": "199.102.107.145:4145"},
    {"socks5": "199.102.104.70:4145"},
    {"socks5": "199.102.106.94:4145"},
]
proxy_counter = 1

# get the building keys from the url
request_params_list = []
for url_ext in url_ext_list:
    # get the last url extension
    last_ext = url_ext.split("/")[-2]

    # if it's not already the building key, get the building key from the last url extension
    split_last_ext_list = last_ext.split("-")
    if len(split_last_ext_list) > 1:
        if "_" not in split_last_ext_list[-1]:
            building_key = split_last_ext_list[-1]
    else:
        building_key = split_last_ext_list[0]

    # cycle through the list of proxies
    proxy = proxies_list[(proxy_counter % proxies_list.__len__()) - 1]
    proxy_counter += 1

    # append the building key, url and proxy to the param_list
    request_params_list.append((url_ext, building_key, proxy))

# %%
print(request_params_list[0:10])
# Out:
# [('/apartments/seattle-wa/the-central/65fNrx/', '65fNrx', {'socks5': '72.210.221.197:4145'}), ('/apartments/seattle-wa/mckenzie/B6n8HF/', 'B6n8HF', {'socks5': '199.229.254.129:4145'}), ('/apartments/seattle-wa/beam/Bct5Jf/', 'Bct5Jf', {'socks5': '74.119.147.209:4145'}), ('/apartments/seattle-wa/adell-apartments/9WLpQz/', '9WLpQz', {'socks5': '68.1.210.163:4145'}), ('/apartments/seattle-wa/alta-arlo/BwyyfK/', 'BwyyfK', {'socks5': '184.178.172.17:4145'}), ('/apartments/seattle-wa/junction-47/62rMRD/', '62rMRD', {'socks5': '142.54.228.193:4145'}), ('/apartments/seattle-wa/beacon-view/5XjNLh/', '5XjNLh', {'socks5': '70.166.167.55:57745'}), ('/b/the-loop-at-green-lake-seattle-wa-BcTtZS/', 'BcTtZS', {'socks5': '184.181.217.201:4145'}), ('/apartments/seattle-wa/624-yale-apartments/9VWkdH/', '9VWkdH', {'socks5': '107.152.98.5:4145'}), ('/apartments/seattle-wa/mason-%26-main/Bjb3nV/', 'Bjb3nV', {'socks5': '72.221.171.130:4145'})]

# %% [markdown]
# ### makes html requests to each building's page and extracts information from zillow's backend server and store it in a response list

# %%
import requests
import time
from fake_useragent import UserAgent

# 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Mobile Safari/537.36'
# make a fake_useragent object
ua = UserAgent()

failed_request_count = 0
timeout = 1
# make a request for each listing and store the response in the response_list
response_list = []


for url_ext, building_key, proxy in request_params_list:
    # the `header` parameter includes information about your browser's current status.  important for preventing captia prompts from zillow
    headers = {
        "authority": "www.zillow.com",
        "accept": "*/*",
        "accept-language": "en-US,en;q=0.9",
        "client-id": "vertical-living",
        "content-type": "text/plain",
        "dnt": "1",
        "origin": "https://www.zillow.com",
        "referer": "https://www.zillow.com" + url_ext,
        "sec-ch-ua": '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
        "sec-ch-ua-mobile": "?1",
        "sec-ch-ua-platform": '"Android"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": ua.random,
    }

    data = (
        '{"operationName":"BuildingQuery","variables":{"buildingKey":'
        + '"'
        + building_key
        + '"'
        + ',"cache":false,"latitude":null,"longitude":null,"lotId":null,"update":true},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"a6b5cd248233c9b3da074a0c6daacf6e6388a9b3a7de3347043b2e1b41d095b6"}}}'
    )

    response = requests.post(
        "https://www.zillow.com/graphql/",
        headers=headers,
        data=data,
        proxies=proxy,
    )

    # append the response if the response went through
    if response.status_code == 200:
        response_list.append(response)
    else:
        failed_request_count += 1

    # wait before the next request
    time.sleep(timeout)

# %%
for response in response_list[0:50]:
    print(response.text)
# Out:
# {"data":{"building":{"regionIds":{"city":16037,"__typename":"RegionIds"},"adTargets":{"premieragent":"no","fsbid":"100066","aamgnrc1":"2203 E Union St APT 607","city":"Seattle","state":"WA","zip":"98122","mlat":"47612637","mlong":"-1223032","listtp":"building","proptp":"apt","sqft":"457,499,665,672,683,685,705,792","sqftrange":"0-500,500-1000","price":"2080,2085,2420,2570,2595,2610,2667","prange":"2000-2500,2500-3000","bd":"0,1","pid":"1151005440","ba":"1"},"__typename":"Building","breadcrumbs":[{"path":"https://www.zillow.com/wa/apartments/","text":"WA","gaLabel":"State","__typename":"Breadcrumb"},{"path":"https://www.zillow.com/king-county-wa/apartments/","text":"King County","gaLabel":"County","__typename":"Breadcrumb"},{"path":"https://www.zillow.com/seattle-wa/apartments/","text":"Seattle","gaLabel":"City","__typename":"Breadcrumb"},{"path":"https://www.zillow.com/seattle-wa-98122/apartments/","text":"98122","gaLabel":"Zipcode","__typename":"Breadcrumb"},{"path":"https://www.zillow.com/minor-seattle-wa/apartments/","text":"Minor","gaLabel":"Neighborhood","__typename":"Breadcrumb"}],"buildingName":"The Central","streetAddress":"2203 E Union St","latitude":47.612638,"longitude":-122.303197,"streetViewTileImageUrlLocationModuleLatLong":"https://maps.googleapis.com/maps/api/streetview?location=47.612638,-122.303197&size=427x115&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=ms-iaNJK_M0hsUsR8JhzxPCBu-4=","streetViewTileImageUrlLocationModuleAddress":"https://maps.googleapis.com/maps/api/streetview?location=2203%20E%20Union%20St%2C%20Seattle%2C%20WA%2098122&size=427x115&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=cyD0nujXpIgVwM95iwVD8Ovv1WE=","lotId":"1151005440","streetViewMetadataUrlMediaWallLatLong":"https://maps.googleapis.com/maps/api/streetview/metadata?location=47.612638,-122.303197&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=bUBZoQJIRF64dJawK11TM63wxF0=","streetViewMetadataUrlMediaWallAddress":"https://maps.googleapis.com/maps/api/streetview/metadata?location=2203%20E%20Union%20St%2C%20Seattle%2C%20WA%2098122&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=2uhSvXFjQ3XVvuh48DRX1WKvgbY=","mapTileGoogleMapUrlLocationModule":"https://maps.googleapis.com/maps/api/staticmap?center=47.612638,-122.303197&zoom=14&size=427x216&maptype=roadmap&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&scale=1&signature=PTsTbdgKqVUBxUXDIcE0j_fPH-k=","mapTileGoogleMapUrlFullWidthMax":"https://maps.googleapis.com/maps/api/staticmap?center=47.612638,-122.303197&zoom=16&size=1920x234&maptype=roadmap&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&scale=1&signature=AgFoh39vgIRKdlGIqOY4pWat8Rk=","address":{"streetAddress":"2203 E Union St","city":"Seattle","state":"WA","zipcode":"98122","__typename":"Address","neighborhood":null},"streetViewTileImageUrlHalfWidthLatLong":"https://maps.googleapis.com/maps/api/streetview?location=47.612638,-122.303197&size=512x234&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=tuHDsnipAWK4shEEq7svcipFZjo=","streetViewTileImageUrlHalfWidthAddress":"https://maps.googleapis.com/maps/api/streetview?location=2203%20E%20Union%20St%2C%20Seattle%2C%20WA%2098122&size=512x234&key=AIzaSyBdka2nwqeknSXr-TkzLcVMbaJEx4CkZEM&source=outdoor&signature=5GjpVXtUBtchdalH6P4sgI1OD58=","city":"Seattle","state":"WA","zipcode":"98122","isWaitlisted":false,"contactInfo":{"contactType":"FOR_RENT","providerListingID":"4s6newg5bt8z5","__typename":"ContactInfo","rentalApplicationsAcceptedType":"NOT_ELIGIBLE"},"isLandlordLiaisonProgram":false,"buildingType":"FOR_RENT","isInstantTourEnabled":false,"isInstantTourCancellable":false,"bestGuessTimezone":"America/Los_Angeles","rentalInstantTour":null,"listingFeatureType":"featured-ppc","photoCount":30,"amenitiesVRModels":null,"videos":[],"galleryPhotos":[{"caption":null,"mixedSources":{"webp":[{"url":"https://photos.zillowstatic.com/fp/1564a93fab4271af636e261212e9f287-d_d.webp","width":800,"__typena ...

# %% [markdown]
# ### iterate through each response in response_list and performs a few steps:
# 1. parse it into a python dict
# 2. Extract the `building` key from the dict
# 3. appends it to the `bld_info_list`
# 4. removes all the useless keys from the each dict in the `bld_info_list`
#
# The object from the reponse represents a python dict (or more precisely a dict of dicts), and the dictionary that contains the relevent building information is in the `building` dictionary.  This block iterates through each response and extracts that `building` dictionary to parse later

# %%
import json

bld_info_list = []
json_parse_error_count = 0
for response in response_list:
    # 1. parse the response into a python dict, if it fails to parse the response, increase the error count
    try:
        raw_bld_info_dict = json.loads(response.text)

        # 2. extract the building key
        for key, value in raw_bld_info_dict.items():
            if key == "data":
                for key, value in value.items():
                    if key == "building":
                        bld_info_dict = value

        # append the listing information to the listing information list
        bld_info_list.append(bld_info_dict)

    except json.JSONDecodeError as e:
        json_parse_error_count += 1

# 4. removes the useless keys
useless_keys = [
    "regionIds",
    "adTargets",
    "streetAddress",
    "__typename",
    "breadcrumbs",
    "streetViewTileImageUrlLocationModuleLatLong",
    "streetViewTileImageUrlLocationModuleAddress",
    "streetViewMetadataUrlMediaWallLatLong",
    "streetViewMetadataUrlMediaWallAddress",
    "mapTileGoogleMapUrlLocationModule",
    "mapTileGoogleMapUrlFullWidthMax",
    "streetViewTileImageUrlHalfWidthLatLong",
    "streetViewTileImageUrlHalfWidthAddress",
    "isWaitlisted",
    "isInstantTourEnabled",
    "isInstantTourCancellable",
    "bestGuessTimezone",
    "rentalInstantTour",
    "amenitiesVRModels",
    "galleryPhotos",
    "galleryAmenityPhotos",
    "fullAddress",
    "bdpUrl",
    "zpid",
    "buildingPhoneNumber",
    "county",
    "ungroupedUnits",
    "nearbyCities",
    "nearbyNeighborhoods",
    "country",
    "nearbyZipcodes",
    "nearbyBuildingLinks",
    "comps",
    "ppcLink",
    "reviewsInfo",
    "housingConnector",
    "localProtections",
    "buildingRentalPremiumPackagesInfo",
    "homeInsights",
    "bestMatchedUnit",
    "photos",
    "amenityPhotos",
    "staticMap",
    "staticMapSatellite",
    "streetViewLatLong",
    "streetViewAddress",
    "thirdPartyVirtualTours",
    "currency",
    "specialOffers",
    "listingMetadata",
    "vaLoanStatus",
    "engrain",
    "homeTypes",
    "providerInfoList",
    "unitsVRModels",
    "city",
    "state",
    "contactInfo",
]

for bld_info_dict in bld_info_list:
    for key in useless_keys:
        if key in bld_info_dict:
            del bld_info_dict[key]

# dump the contents into a json file
with open(
    "C:/python-projects/zillow_webscraper/issues/zillow-webscraper/data/raw_v2/raw_listings_3.json",
    "w",
) as f:
    f.write(json.dumps(bld_info_list))
