# %%
import requests
import json
import pandas as pd

# make a list of responses to store the html requests
response_list = []

# define the headers for the request
headers = {
    "authority": "www.zillow.com",
    "accept": "*/*",
    "accept-language": "en-US,en;q=0.9,it-IT;q=0.8,it;q=0.7",
    "dnt": "1",
    "sec-ch-ua": '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
    "sec-ch-ua-mobile": "?1",
    "sec-ch-ua-platform": '"Android"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Mobile Safari/537.36",
}

# define the parameters for the request such as the city, mapbounds, region and filter state

city = "seattle-wa"

# IMPORTANT** for search results with number of listings above 800, you must create a filter to make sure the number of listings stay under 800.  In this case, limiting the minimum and maximum rent will keep the number of listings under 800.
rent_intervals = [(0, 1699), (1700, 2199), (2200, 3199), (3200, 9000)]

# pagination for each search result
max_pages = 20
current_page = 1

# make a list of information to make the requests
request_info_list = []

# iterate through each rent_interval filter
for min_rent, max_rent in rent_intervals:
    # iterate through each page for the current rent_interval filter
    while current_page <= max_pages:
        params = {
            "mapBounds": {
                "west": -122.465159,
                "east": -122.224433,
                "south": 47.491912,
                "north": 47.734145,
            },
            "regionSelection": [{"regionId": 16037, "regionType": 6}],
            "filterState": {
                "fsba": {"value": False},
                "fsbo": {"value": False},
                "nc": {"value": False},
                "fore": {"value": False},
                "cmsn": {"value": False},
                "auc": {"value": False},
                "fr": {"value": True},
                "ah": {"value": True},
                "mf": {"value": False},
                "land": {"value": False},
                "manu": {"value": False},
                # monthy rent
                "mp": {"max": max_rent, "min": min_rent},
            },
            "pagination": {"currentPage": current_page},
        }
        # append the request information to the request_info_list
        request_info_list.append((current_page, params))

        # increase the page counter
        current_page += 1

    # reset the page counter
    current_page = 1

# %%
# iterate through each page in the request_info_list
for current_page, params in request_info_list:
    # store the html request for the current page of the current rent_interval
    response = requests.get(
        "https://www.zillow.com/"
        + f"{city}/"
        + "rentals/"
        + f"{current_page}_p/"
        + "?searchQueryState=",
        headers=headers,
        params=params,
    )

    # append the response to the response_list
    response_list.append(response)

# %%
from bs4 import BeautifulSoup


def parse_responses(response_list: list) -> list:
    """Parse the html responses into BeautifulSoup objects"""
    soup_list = []
    for response in response_list:
        soup = BeautifulSoup(response.text, "html.parser")
        soup_list.append(soup)
    return soup_list


soup_list = parse_responses(response_list)

# %%
print(soup_list[0].prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
#  <head>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&amp;display=swap" rel="stylesheet"/>
#   <style type="text/css">
#    @font-face{font-display:swap;font-family:Ivar Headline;font-style:normal;font-weight:600;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff2) format(&quot;woff2&quot;),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff) format(&quot;woff&quot;);unicode-range:u+0000-001f,u+0080-200f,u+2020-faff,u+fb10-ffff}@font-face{font-display:swap;font-family:Ivar Headline;font-style:normal;font-weight:600;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff2) format(&quot;woff2&quot;),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff) format(&quot;woff&quot;);unicode-range:u+0020-007f,u+201?,u+fb0?}
#   </style>
#   <style type="text/css">
#    @font-face{font-display:swap;font-family:Ivar Headline Subset;font-style:normal;font-weight:600;src:url(&quot;data:application/x-font-woff2;charset=utf-8;base64,...&quot;) format(&quot;woff2&quot;);unicode-range:u+0020,u+0041-005a,u+0061-007a}
#   </style>
#   <script>
#    (function(n,a,e){var r="v2",i="fontsVersion",t="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&display=swap",c="//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-",o="",s="",l="",f="",u={};var S=function(){var e="__zstorage__";try{localStorage.setItem(e,e);localStorage.removeItem(e);return true}catch(e){return false}}();var p=function(){try{return a.createElement("link").relList.supports("prefetch")}catch(e){return false}}();function d(e){var t=n.requestIdleCallback;t&&t(e)||setTimeout(e,1)}function v(e){var t=a.createElement("style");t.type="text/css";t.appendChild(a.createTextNode(e));a.head.appendChild(t)}function y(e,t){var n=a.createElement("link");n.rel=t;n.href=e;a.head.appendChild(n)}u.setOpenSansFallbackStyle=function(e){f=e};u.insertOpenSansFallbackStyle=function(){f&&v(f)};u.insertOpenSansStyle=function(){y(t,"stylesheet")};u.setIvarFallbackStyle=function(e){l=e};u.insertIvarFallbackStyle=function(){l&&v(l)};u.setIvarStyle=function(e){o=e};u.insertIvarStyle=function(){o&&v(o)};u.setIvarSubsetStyle=function(e){s=e};u.insertIvarSubsetStyle=function(){s&&v(s)};u.prefetchIvarResources=function(){if(p){y(c+"core.woff2","prefetch");y(c+"extended.woff2","prefetch")}};u.prefetchOpenSansResources=function(){if(p){y(t,"prefetch")}};u.initFirstLoad=function(e){e=e||{};localStorage[i]=r;u.insertIvarSubsetStyle();var t=e.prefetcher||function(e){n.addEventListener("load",function(){d(e)})};t(function(){u.prefetchIvarResources()})};u.initSecondLoad=function(){u.insertIvarStyle()};u.init=function(e){u.insertOpenSansFallbackStyle();u.insertIvarFallbackStyle();u.insertOpenSansStyle();if(!S||localStorage[i]===r){u.initSecondLoad()}else{u.initFirstLoad(e)}};n[e]=n[e]||u})(window,document,"ZillowFontLoader");
#                         ZillowFontLoader.init();
#   </script>
#   <script id="web-platform-manifest-injection-id">
#    (function () { var manifest = {"manifest":{"showcase-page-subapp":{"subAppName":"showcase-page-subapp","scope":"ShowcasePageSubapp","id":"showcase-page-subapp","createdDateTime":"2022-12-09T00:03:22.534Z","updatedDateTime":"2023-05-12T18:17:40.767Z","versions":[{"version":"main.3817927.78982387","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/showcase-page-subapp/showcase-page-subapp.main.3817927.78982387/web/showcase-page-subapp-remoteEntry.js","remoteEntryServerUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/showcase-page-subapp/showcase-page-subapp.main.3817927.78982387/node/showcase-page-subapp-remoteEntry.js"}]},"search-page-sub-app":{"subAppName":"search-page-sub-app","scope":"SearchPageSubApp","id":"search-page-sub-app","createdDateTime":"2022-10-18T01:17:31.810Z","updatedDateTime":"2023-05-10T21:52:53.873Z","versions":[{"version":"main.3758805.8bdad6b7","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/search-page-sub-app/search-page-sub-app.main.3758805.8bdad6b7/web/search-page-sub-app-remoteEntry.js","remoteEntryServerUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/search-page-sub-app/search-page-sub-app.main.3758805.8bdad6b7/node/search-page-sub-app-remoteEntry.js"}]},"for-rent-page-sub-app":{"subAppName":"for-rent-page-sub-app","scope":"ForRentPageSubApp","id":"for-rent-page-sub-app","createdDateTime":"2022-10-12T20:48:10.196Z","updatedDateTime":"2023-05-17T20:14:52.808Z","versions":[{"version":"master.3840228.8b28d1c2","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/for-rent-page-sub-app/for-rent-page-sub-app.master.3840228.8b28d1c2/web/for-rent-page-sub-app-remoteEntry.js","remoteEntryServerUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/for-rent-page-sub-app/for-rent-page-sub-app.master.3840228.8b28d1c2/node/for-rent-page-sub-app-remoteEntry.js"}]},"not-for-sale-page-sub-app":{"subAppName":"not-for-sale-page-sub-app","scope":"NotForSalePageSubApp","id":"not-for-sale-page-sub-app","createdDateTime":"2022-08-02T19:46:10.845Z","updatedDateTime":"2023-05-03T22:39:00.230Z","versions":[{"version":"master.3765842.c52f724b","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/not-for-sale-page-sub-app/not-for-sale-page-sub-app.master.3765842.c52f724b/web/not-for-sale-page-sub-app-remoteEntry.js","remoteEntryServerUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/not-for-sale-page-sub-app/not-for-sale-page-sub-app.master.3765842.c52f724b/node/not-for-sale-page-sub-app-remoteEntry.js"}]},"building-admin-sub-app":{"subAppName":"building-admin-sub-app","scope":"BuildingAdminSubApp","id":"building-admin-sub-app","createdDateTime":"2022-12-08T18:04:06.054Z","updatedDateTime":"2022-12-08T18:15:22.385Z","versions":[]},"spencerwa-test":{"subAppName":"spencerwa-test","scope":"spencerwa-test","id":"spencerwa-test","createdDateTime":"2022-08-02T18:48:55.483Z","versions":[],"updatedDateTime":"2022-08-02T18:48:55.483Z"},"home-details":{"subAppName":"home-details","scope":"HomeDetails","id":"home-details","createdDateTime":"2023-03-21T16:49:25.005Z","updatedDateTime":"2023-04-03T21:56:39.855Z","versions":[{"version":"main.3597494.d644d2d4","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/home-details/home-details.main.3597494.d644d2d4/web/home-details-remoteEntry.js","remoteEntryServerUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/home-details/home-details.main.3597494.d644d2d4/node/home-details-remoteEntry.js"}]},"building-page-sub-app":{"subAppName":"building-page-sub-app","scope":"BuildingPageSubApp","id":"building-page-sub-app","createdDateTime":"2022-11-29T23:15:03.360Z","updatedDateTime":"2023-05-17T18:30:52.470Z","versions":[{"version":"master.3840765.d8f84822","remoteEntryClientUrl":"https://s.zillowstatic.com/s3/web-platform/sub-apps/building-page-sub-app/building-page-sub-app.master.3840765.d8f84822/web/building-page-sub-app-remoteEntry.js","re ...
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="2" name="next-head-count"/>
#   <noscript data-n-css="">
#   </noscript>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/webpack-d6068f7.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/framework-d90d701.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/main-a32cfcb.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/pages/_app-401e9e0.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/946-e48d65b.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/415-e4edc4d.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/498-61b5959.js" rel="preload"/>
#   <link as="script" href="https://www.zillowstatic.com/s3/shopper-platform/_next/static/chunks/pages/search-page-64469ca.js" rel="preload"/>
#   <style data-styled="" data-styled-version="5.3.6">
#    .eUmsgT{display:inline-block;vertical-align:top;stroke:currentColor;fill:currentColor;height:1em;width:1em;}/*!sc*/
# .fDzHdQ{display:inline-block;vertical-align:top;stroke:currentColor;fill:currentColor;height:1em;width:1em;height:16px;width:16px;}/*!sc*/
# .enZLYE{display:inline-block;vertical-align:top;stroke:currentColor;fill:currentColor;height:1em;width:1em;height:32px;width:32px;}/*!sc*/
# data-styled.g3[id="Icon-c11n-8-84-0__sc-13llmml-0"]{content:"eUmsgT,fDzHdQ,enZLYE,"}/*!sc*/
# .euHQEN{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:14px;line-height:24px;margin:0;}/*!sc*/
# .euHQEN > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:5px;}/*!sc*/
# .euHQEN strong,.euHQEN b{font-weight:700;}/*!sc*/
# .euHQEN em,.euHQEN i{font-style:italic;}/*!sc*/
# .qxgaF{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:16px;line-height:24px;margin:0;}/*!sc*/
# .qxgaF > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .qxgaF strong,.qxgaF b{font-weight:700;}/*!sc*/
# .qxgaF em,.qxgaF i{font-style:italic;}/*!sc*/
# .ccKCIk{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:12px;line-height:16px;margin:0;margin-bottom:8px;}/*!sc*/
# .ccKCIk > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:2px;}/*!sc*/
# .ccKCIk strong,.ccKCIk b{font-weight:700;}/*!sc*/
# .ccKCIk em,.ccKCIk i{font-style:italic;}/*!sc*/
# .kFMWow{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:12px;line-height:16px;margin:0;margin-bottom:16px;}/*!sc*/
# .kFMWow > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:2px;}/*!sc*/
# .kFMWow strong,.kFMWow b{font-weight:700;}/*!sc*/
# .kFMWow em,.kFMWow i{font-style:italic;}/*!sc*/
# .iGOzRq{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:12px;line-height:16px;margin:0;}/*!sc*/
# .iGOzRq > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:2px;}/*!sc*/
# .iGOzRq strong,.iGOzRq b{font-weight:700;}/*!sc*/
# .iGOzRq em,.iGOzRq i{font-style:italic;}/*!sc*/
# .fMBLJF{color:#54545A;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:10px;line-height:16px;margin:0;}/*!sc*/
# .fMBLJF > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:3px;}/*!sc*/
# .fMBLJF strong,.fMBLJF b{font-weight:700;}/*!sc*/
# .fMBLJF em,.fMBLJF i{font-style:italic;}/*!sc*/
# data-styled.g5[id="Text-c11n-8-84-0__sc-aiai24-0"]{content:"euHQEN,qxgaF,ccKCIk,kFMWow,iGOzRq,fMBLJF,"}/*!sc*/
# .kKKctC{cursor:pointer;font-family:inherit;font-size:inherit;font-weight:inherit;line-height:inherit;-webkit-text-decoration:underline;text-decoration:underline;outline:none;box-shadow:none;}/*!sc*/
# .kKKctC:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.kKKctC:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .kKKctC,.kKKctC:focus{color:#0D4599;}/*!sc*/
# .kKKctC:visited{color:#5B33AD;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kKKctC:hover:not(:disabled){color:#001751;}}/*!sc*/
# .kKKctC:active{color:#001751;}/*!sc*/
# data-styled.g8[id="Anchor-c11n-8-84-0__sc-hn4bge-0"]{content:"kKKctC,"}/*!sc*/
# .jkzjZt{-webkit-appearance:none;-moz-appearance:none;appearance:none;width:auto;margin:0;padding-left:16px;padding-right:16px;background-color:#F6F6FA;border:1px solid;border-color:#D1D1D5;border-radius:4px;box-sizing:border-box;caret-color:#006AFF;cursor:text;outline:none;box-shadow:none;outline:none;box-shadow:none;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:16px;line-height:24px;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;color:#54545A;width:auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .jkzjZt[disabled]{background-color:#F6F6FA;border-color:#D1D1D5;color:#2A2A33;}/*!sc*/
# .jkzjZt::-webkit-input-placeholder{color:#596B82;}/*!sc*/
# .jkzjZt::-moz-placeholder{color:#596B82;}/*!sc*/
# .jkzjZt:-ms-input-placeholder{color:#596B82;}/*!sc*/
# .jkzjZt::placeholder{color:#596B82;}/*!sc*/
# .jkzjZt:-webkit-autofill{box-shadow:0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .jkzjZt.edge-autofilled{background-color:#E0F2FF !important;}/*!sc*/
# .jkzjZt:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.jkzjZt:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .jkzjZt:focus:-webkit-autofill{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF,0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .jkzjZt:active:not([disabled]),.jkzjZt:focus{background-color:#FFF;}/*!sc*/
# .jkzjZt:hover:not([disabled]),.jkzjZt:active:not([disabled]),.jkzjZt:focus{border-color:#006AFF;}/*!sc*/
# .jkzjZt[aria-invalid="true"]{caret-color:#A3000B;}/*!sc*/
# .jkzjZt[aria-invalid="true"],.jkzjZt[aria-invalid="true"][disabled],.jkzjZt[aria-invalid="true"]:hover,.jkzjZt[aria-invalid="true"]:active,.jkzjZt[aria-invalid="true"]:focus{border-color:#A3000B;}/*!sc*/
# .jkzjZt[disabled]{cursor:default;opacity:0.4;}/*!sc*/
# .jkzjZt[readonly]{background-color:transparent;padding-left:0;padding-right:0;}/*!sc*/
# .jkzjZt[readonly],.jkzjZt[readonly]:hover,.jkzjZt[readonly]:active,.jkzjZt[readonly]:focus{border-color:transparent;}/*!sc*/
# .jkzjZt[disabled]{color:#54545A;}/*!sc*/
# data-styled.g9[id="StyledAdornment-c11n-8-84-0__sc-1kerx9v-0"]{content:"jkzjZt,"}/*!sc*/
# .khogqF{border-top-left-radius:0;border-bottom-left-radius:0;border-left:0;}/*!sc*/
# data-styled.g11[id="AdornmentRight-c11n-8-84-0__sc-1kerx9v-2"]{content:"khogqF,"}/*!sc*/
# .kdAbnq{-webkit-appearance:none;-moz-appearance:none;appearance:none;width:100%;margin:0;padding-left:16px;padding-right:16px;background-color:#F6F6FA;border:1px solid;border-color:#D1D1D5;border-radius:4px;box-sizing:border-box;caret-color:#006AFF;cursor:text;outline:none;box-shadow:none;outline:none;box-shadow:none;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:16px;line-height:24px;padding-top:5px;padding-bottom:5px;line-height:24px;height:auto;}/*!sc*/
# .kdAbnq[disabled]{background-color:#F6F6FA;border-color:#D1D1D5;color:#2A2A33;}/*!sc*/
# .kdAbnq::-webkit-input-placeholder{color:#596B82;}/*!sc*/
# .kdAbnq::-moz-placeholder{color:#596B82;}/*!sc*/
# .kdAbnq:-ms-input-placeholder{color:#596B82;}/*!sc*/
# .kdAbnq::placeholder{color:#596B82;}/*!sc*/
# .kdAbnq:-webkit-autofill{box-shadow:0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .kdAbnq.edge-autofilled{background-color:#E0F2FF !important;}/*!sc*/
# .kdAbnq:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.kdAbnq:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .kdAbnq:focus:-webkit-autofill{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF,0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .kdAbnq:active:not([disabled]),.kdAbnq:focus{background-color:#FFF;}/*!sc*/
# .kdAbnq:hover:not([disabled]),.kdAbnq:active:not([disabled]),.kdAbnq:focus{border-color:#006AFF;}/*!sc*/
# .kdAbnq[aria-invalid="true"]{caret-color:#A3000B;}/*!sc*/
# .kdAbnq[aria-invalid="true"],.kdAbnq[aria-invalid="true"][disabled],.kdAbnq[aria-invalid="true"]:hover,.kdAbnq[aria-invalid="true"]:active,.kdAbnq[aria-invalid="true"]:focus{border-color:#A3000B;}/*!sc*/
# .kdAbnq[disabled]{cursor:default;opacity:0.4;}/*!sc*/
# .kdAbnq[readonly]{background-color:transparent;padding-left:0;padding-right:0;}/*!sc*/
# .kdAbnq[readonly],.kdAbnq[readonly]:hover,.kdAbnq[readonly]:active,.kdAbnq[readonly]:focus{border-color:transparent;}/*!sc*/
# data-styled.g13[id="Input-c11n-8-84-0__sc-4ry0fw-0"]{content:"kdAbnq,"}/*!sc*/
# .kzwQnH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .kzwQnH > .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# .kzwQnH > .AdornmentLeft-c11n-8-84-0__sc-1kerx9v-1{-webkit-order:-1;-ms-flex-order:-1;order:-1;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0{min-width:0;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:-webkit-autofill ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{box-shadow:0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0.edge-autofilled ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{background-color:#E0F2FF;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:active:not([disabled]) ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:focus ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{background-color:#FFF;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:hover:not([disabled]) ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:active:not([disabled]) ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:focus ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{border-color:#006AFF;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:focus{box-shadow:none;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0:focus:-webkit-autofill{box-shadow:0 0 0 1000px #E0F2FF inset;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[disabled] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{cursor:default;opacity:0.4;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[disabled] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[disabled] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0:hover,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[disabled] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0:active,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[disabled] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0:focus{background-color:#F6F6FA;border-color:#D1D1D5;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[readonly] ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[readonly]:hover ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[readonly]:active ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0,.kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0[readonly]:focus ~ .StyledAdornment-c11n-8-84-0__sc-1kerx9v-0{background-color:transparent;border-color:transparent;}/*!sc*/
# .kzwQnH:focus-within{border-radius:4px;box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# .kzwQnH > .Input-c11n-8-84-0__sc-4ry0fw-0{padding-right:0;border-right:0;border-top-right-radius:0;border-bottom-right-radius:0;}/*!sc*/
# data-styled.g14[id="StyledAdornedInput-c11n-8-84-0__sc-1kgphdl-0"]{content:"kzwQnH,"}/*!sc*/
# .lihqJq{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# data-styled.g43[id="IconChevronLeft-c11n-8-84-0__sc-ddr5cu-0"]{content:"lihqJq,"}/*!sc*/
# .gGBmqR{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# data-styled.g47[id="IconChevronRight-c11n-8-84-0__sc-19mpgrq-0"]{content:"gGBmqR,"}/*!sc*/
# .iUkYmA{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}/*!sc*/
# data-styled.g54[id="IconChevronUpOutline-c11n-8-84-0__sc-1d3o5nk-0"]{content:"iUkYmA,"}/*!sc*/
# .fOwaKd{-webkit-transform:scaleY(-1);-ms-transform:scaleY(-1);transform:scaleY(-1);}/*!sc*/
# data-styled.g67[id="IconSortAscending-c11n-8-84-0__sc-j24y04-0"]{content:"fOwaKd,"}/*!sc*/
# .ksTbUD{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;outline:none;box-shadow:none;border:0;background:none;padding:0;text-align:initial;-webkit-appearance:none;margin-bottom:8px;padding-bottom:8px;}/*!sc*/
# .ksTbUD > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .ksTbUD,.ksTbUD:active{color:#0D4599;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ksTbUD:hover:not(:disabled){-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .ksTbUD:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.ksTbUD:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .ksTbUD:not(:disabled){cursor:pointer;}/*!sc*/
# .cLKtsN{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:14px;line-height:24px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;outline:none;box-shadow:none;border:0;background:none;padding:0;text-align:initial;-webkit-appearance:none;}/*!sc*/
# .cLKtsN > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:5px;}/*!sc*/
# .cLKtsN,.cLKtsN:active{color:#2A2A33;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.cLKtsN:hover:not(:disabled){-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .cLKtsN:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.cLKtsN:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .cLKtsN:not(:disabled){cursor:pointer;}/*!sc*/
# .kjdMUs{color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:400;font-size:14px;line-height:24px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;outline:none;box-shadow:none;border:0;background:none;padding:0;text-align:initial;-webkit-appearance:none;}/*!sc*/
# .kjdMUs > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:5px;}/*!sc*/
# .kjdMUs,.kjdMUs:active{color:#0D4599;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kjdMUs:hover:not(:disabled){-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .kjdMUs:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.kjdMUs:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .kjdMUs:not(:disabled){cursor:pointer;}/*!sc*/
# data-styled.g70[id="StyledTextButton-c11n-8-84-0__sc-n1gfmh-0"]{content:"ksTbUD,cLKtsN,kjdMUs,"}/*!sc*/
# .vPHNJ{border:0;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:rect(0 0 0 0);clip-path:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;}/*!sc*/
# data-styled.g77[id="VisuallyHidden-c11n-8-84-0__sc-t8tewe-0"]{content:"vPHNJ,"}/*!sc*/
# .bqhATt{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:14px;line-height:24px;padding-top:5px;padding-bottom:5px;line-height:24px;height:auto;}/*!sc*/
# .bqhATt:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.bqhATt:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .bqhATt,.bqhATt:focus,.bqhATt:visited,.bqhATt:disabled{background-color:#FFF;border-color:#A7A6AB;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.bqhATt:hover:not(:disabled){background-color:#F1F1F4;border-color:#A7A6AB;color:#2A2A33;}}/*!sc*/
# .bqhATt[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:4px;padding-bottom:4px;line-height:24px;height:auto;}/*!sc*/
# .bqhATt:active:not(:disabled){background-color:#D1D1D5;border-color:#54545A;color:#2A2A33;}/*!sc*/
# .bqhATt:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .bqhATt > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:5px;}/*!sc*/
# .lbzBdN{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;}/*!sc*/
# .lbzBdN:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.lbzBdN:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .lbzBdN,.lbzBdN:focus,.lbzBdN:visited,.lbzBdN:disabled{background-color:#FFF;border-color:#006AFF;color:#006AFF;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.lbzBdN:hover:not(:disabled){background-color:#F2FAFF;border-color:#0D4599;color:#0D4599;}}/*!sc*/
# .lbzBdN[aria-pressed="true"][aria-pressed="true"]{background-color:#001751;border-color:#001751;color:#FFF;border-width:2px;padding-left:15px;padding-right:15px;padding-top:8px;padding-bottom:8px;line-height:24px;height:auto;}/*!sc*/
# .lbzBdN:active:not(:disabled){background-color:#E0F2FF;border-color:#001751;color:#001751;}/*!sc*/
# .lbzBdN:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .lbzBdN > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .chqnye{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;}/*!sc*/
# .chqnye:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.chqnye:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .chqnye,.chqnye:focus,.chqnye:visited,.chqnye:disabled{background-color:#FFF;border-color:#A7A6AB;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.chqnye:hover:not(:disabled){background-color:#F1F1F4;border-color:#A7A6AB;color:#2A2A33;}}/*!sc*/
# .chqnye[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:8px;padding-bottom:8px;line-height:24px;height:auto;}/*!sc*/
# .chqnye:active:not(:disabled){background-color:#D1D1D5;border-color:#54545A;color:#2A2A33;}/*!sc*/
# .chqnye:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .chqnye > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .euVHOK{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;padding-top:15px;padding-bottom:15px;line-height:24px;height:auto;}/*!sc*/
# .euVHOK:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.euVHOK:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .euVHOK,.euVHOK:focus,.euVHOK:visited,.euVHOK:disabled{background-color:#FFF;border-color:#A7A6AB;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.euVHOK:hover:not(:disabled){background-color:#F1F1F4;border-color:#A7A6AB;color:#2A2A33;}}/*!sc*/
# .euVHOK[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:14px;padding-bottom:14px;line-height:24px;height:auto;}/*!sc*/
# .euVHOK:active:not(:disabled){background-color:#D1D1D5;border-color:#54545A;color:#2A2A33;}/*!sc*/
# .euVHOK:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .euVHOK > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .cWeIzq{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;}/*!sc*/
# .cWeIzq:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.cWeIzq:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .cWeIzq,.cWeIzq:focus,.cWeIzq:visited,.cWeIzq:disabled{background-color:transparent;border-color:#FFF;color:#FFF;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.cWeIzq:hover:not(:disabled){background-color:#F1F1F4;border-color:#FFF;color:#2A2A33;}}/*!sc*/
# .cWeIzq[aria-pressed="true"][aria-pressed="true"]{border-width:2px;padding-left:15px;padding-right:15px;padding-top:8px;padding-bottom:8px;line-height:24px;height:auto;}/*!sc*/
# .cWeIzq:active:not(:disabled){background-color:#D1D1D5;border-color:#FFF;color:#2A2A33;}/*!sc*/
# .cWeIzq:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .cWeIzq > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .kvVhac{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:none;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;cursor:default;opacity:0.4;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;}/*!sc*/
# .kvVhac:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.kvVhac:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .kvVhac,.kvVhac:focus,.kvVhac:visited,.kvVhac:disabled{background-color:#FFF;border-color:transparent;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kvVhac:hover:not(:disabled){background-color:#F1F1F4;border-color:transparent;color:#2A2A33;}}/*!sc*/
# .kvVhac[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:8px;padding-bottom:8px;line-height:24px;height:auto;}/*!sc*/
# .kvVhac:active:not(:disabled){background-color:#D1D1D5;border-color:transparent;color:#2A2A33;}/*!sc*/
# .kvVhac:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .kvVhac > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# .hFaVRz{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;width:auto;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:16px;line-height:24px;padding-top:9px;padding-bottom:9px;line-height:24px;height:auto;}/*!sc*/
# .hFaVRz:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.hFaVRz:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .hFaVRz,.hFaVRz:focus,.hFaVRz:visited,.hFaVRz:disabled{background-color:#FFF;border-color:transparent;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hFaVRz:hover:not(:disabled){background-color:#F1F1F4;border-color:transparent;color:#2A2A33;}}/*!sc*/
# .hFaVRz[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:8px;padding-bottom:8px;line-height:24px;height:auto;}/*!sc*/
# .hFaVRz:active:not(:disabled){background-color:#D1D1D5;border-color:transparent;color:#2A2A33;}/*!sc*/
# .hFaVRz:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .hFaVRz > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:4px;}/*!sc*/
# data-styled.g83[id="StyledButton-c11n-8-84-0__sc-wpcbcc-0"]{content:"bqhATt,lbzBdN,chqnye,euVHOK,cWeIzq,kvVhac,hFaVRz,"}/*!sc*/
# .laTxPP{margin-left:8px;}/*!sc*/
# .laTxPP > .Icon-c11n-8-84-0__sc-13llmml-0{display:block;height:16px;width:16px;}/*!sc*/
# .jjxHig{margin-right:8px;}/*!sc*/
# .jjxHig > .Icon-c11n-8-84-0__sc-13llmml-0{display:block;height:24px;width:24px;}/*!sc*/
# data-styled.g84[id="StyledButtonIcon-c11n-8-84-0__sc-wpcbcc-1"]{content:"laTxPP,jjxHig,"}/*!sc*/
# .kCRumU{-webkit-animation:spin 0.5s linear infinite;animation:spin 0.5s linear infinite;color:#006AFF;}/*!sc*/
# @-webkit-keyframes spin{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes spin{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# data-styled.g85[id="StyledSpinner-c11n-8-84-0__sc-zhumcj-0"]{content:"kCRumU,"}/*!sc*/
# .dhKepl{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;text-align:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;box-sizing:border-box;border:1px solid;border-radius:4px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding-left:16px;padding-right:16px;margin:0;-webkit-appearance:none;-webkit-transition-property:background-color,border-color,color;transition-property:background-color,border-color,color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;pointer-events:auto;outline:none;box-shadow:none;position:relative;color:#2A2A33;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-transform:none;font-family:"Open Sans","Adjusted Arial",Tahoma,Geneva,sans-serif;font-weight:700;font-size:14px;line-height:24px;padding-top:5px;padding-bottom:5px;line-height:24px;height:auto;height:36px;width:36px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px;}/*!sc*/
# .dhKepl:focus-visible{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# @supports not selector(:focus-visible){.dhKepl:focus{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}}/*!sc*/
# .dhKepl,.dhKepl:focus,.dhKepl:visited,.dhKepl:disabled{background-color:transparent;border-color:transparent;color:#2A2A33;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.dhKepl:hover:not(:disabled){background-color:#F1F1F4;border-color:transparent;color:#2A2A33;}}/*!sc*/
# .dhKepl[aria-pressed="true"][aria-pressed="true"]{background-color:#F2FAFF;border-color:#006AFF;color:#2A2A33;border-width:2px;padding-left:15px;padding-right:15px;padding-top:4px;padding-bottom:4px;line-height:24px;height:auto;}/*!sc*/
# .dhKepl:active:not(:disabled){background-color:#D1D1D5;border-color:transparent;color:#2A2A33;}/*!sc*/
# .dhKepl:after{content:"";position:absolute;left:0;height:44px;min-width:44px;width:100%;top:50%;margin-top:-22px;}/*!sc*/
# .dhKepl > .Icon-c11n-8-84-0__sc-13llmml-0{margin-top:5px;}/*!sc*/
# .dhKepl[aria-pressed="true"]:disabled{opacity:1;}/*!sc*/
# .dhKepl span > .Icon-c11n-8-84-0__sc-13llmml-0{display:block;height:16px;width:16px;}/*!sc*/
# data-styled.g90[id="StyledIconButton-c11n-8-84-0__sc-1pb8vz8-0"]{content:"dhKepl,"}/*!sc*/
# .vlmfT{padding:16px;background-color:#FFF;cursor:pointer;outline:none;position:relative;-webkit-transition-property:background-color,box-shadow;transition-property:background-color,box-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease;transition-timing-function:ease;border:0 solid #D1D1D5;box-shadow:0 2px 4px 0 rgba(0,0,0,0.3);}/*!sc*/
# @media (min-width:481px){.vlmfT{border-radius:4px;}.vlmfT:after{border-radius:4px;}}/*!sc*/
# .vlmfT:hover,.vlmfT:active{background-color:#F2FAFF;}/*!sc*/
# .vlmfT:after{border:2px solid #006AFF;content:"";display:none;pointer-events:none;position:absolute;speak:none;z-index:1;}/*!sc*/
# .vlmfT[aria-pressed="true"]:after{display:block;}/*!sc*/
# @media (prefers-reduced-motion:reduce){.vlmfT{-webkit-transition:none;transition:none;}}/*!sc*/
# .vlmfT[aria-pressed="true"]{border-color:transparent;}/*!sc*/
# .vlmfT:after{bottom:0;left:0;right:0;top:0;}/*!sc*/
# .vlmfT:hover{box-shadow:0 4px 8px 0 rgba(0,0,0,0.3);}/*!sc*/
# .vlmfT:active:not(:has(:active)){box-shadow:none;}/*!sc*/
# .vlmfT:focus{box-shadow:0 2px 4px 0 rgba(0,0,0,0.3),0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# .vlmfT:focus:hover{box-shadow:0 4px 8px 0 rgba(0,0,0,0.3),0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# .vlmfT:focus:active{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# .vlmfT[aria-pressed="true"],.vlmfT [aria-pressed="true"]:hover,.vlmfT [aria-pressed="true"]:active{box-shadow:none;}/*!sc*/
# .vlmfT[aria-pressed="true"]:focus,.vlmfT [aria-pressed="true"]:focus:hover,.vlmfT [aria-pressed="true"]:focus:active{box-shadow:0 0 0px 1px #FFF,0 0 2px 3px #A6E5FF,0 0 2px 4px #006AFF;}/*!sc*/
# data-styled.g92[id="StyledCard-c11n-8-84-0__sc-rmiu6p-0"]{content:"vlmfT,"}/*!sc*/
# .CqOry{box-sizing:border-box;background-color:#FFF;box-shadow:0 8px 12px 0 rgba(0,0,0,0.3);outline:none;border-radius:8px;position:relative;z-index:100011;border-radius:4px;}/*!sc*/
# .CqOry .DialogClose-c11n-8-84-0__sc-1t0puoj-0{position:absolute;z-index:100013;}/*!sc*/
# .CqOry .DialogLayout-c11n-8-84-0__sc-178ji0w-0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .CqOry .DialogHeader-c11n-8-84-0__sc-1nk3a2m-0{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# .CqOry .DialogBody-c11n-8-84-0__sc-dazfx6-0{overflow-y:auto;-webkit-overflow-scrolling:touch;padding:12px 16px 0;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}/*!sc*/
# .CqOry .DialogBody-c11n-8-84-0__sc-dazfx6-0:after{content:"";display:block;height:12px;}/*!sc*/
# .CqOry .DialogBody-c11n-8-84-0__sc-dazfx6-0 > .StyledDropdownHeading-c11n-8-84-0__sc-dktrpd-0{margin-left:-16px;margin-right:-16px;}/*!sc*/
# .CqOry .DialogBody-c11n-8-84-0__sc-dazfx6-0 > .StyledDropdownHeading-c11n-8-84-0__sc-dktrpd-0:first-child{margin-top:-12px;}/*!sc*/
# .CqOry .DialogFooter-c11n-8-84-0__sc-1xigudn-0{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin:0;padding:12px 16px;}/*!sc*/
# ...
#   <script>
#    if(!window.ProxiedReactAppConfig) { window.ProxiedReactAppConfig = {}; };window.ProxiedReactAppConfig.staticDomain="https://www.zillowstatic.com/";if(!window.ProxiedReactAppConfig["static-user-session-store"]) { window.ProxiedReactAppConfig["static-user-session-store"] = {}; };window.ProxiedReactAppConfig["static-user-session-store"]["user-session-store-loader"]={"loggedIn":"false"};
#   </script>
#   <script>
#    window.lifecycleQueue.addScriptToEvent( ["https://www.zillowstatic.com/static-user-session-store/LIVE/overall-commons-d33db02c1a.js","https://www.zillowstatic.com/static-user-session-store/LIVE/user-session-store-loader/app-1ba188d3c7.js"], "priorityUIReady");
#   </script>
#   <div class="hide" id="analytics">
#    <!-- SiteCatalyst code version: H.22.1 Copyright 1997-2010 Adobe, Inc. More info available at http://www.omniture.com -->
#    <script>
#     !function () {
#                 var n = !1, op = document.cookie && document.cookie.split("; ").filter(function(n){ return n.indexOf("OptanonConsent=") === 0; });
#                 try {
#                     var o = op && op.length > 0 && op[0];
#                     if (void 0 !== o && null != o) {
#                         var i = decodeURIComponent(o).split("&").filter(function(n) { return n.indexOf("groups=") !== -1; });
#                         if(i.length > 0) {
#                             var m = i[0].substring(i[0].indexOf("=")).split(",");
#                             for (var k = 0; k < m.length; k++) {
#                                 m[k].split(":").length > 1 && "3" === m[k].split(":")[0] && "0" === m[k].split(":")[1] && (n = !0)
#                             }
#                         }
#                     }
#                 } catch(e) {}
#                 window['ga-disable-' + 'UA-21174015-56'] = n;
#                 window['disable-analytics'] = n;
#             }();
#    </script>
#    <script>
#     window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#    </script>
#    <script>
#     (function() {
#     function safeDim(isDbg) {
#         try { return  ({"cd6":null,"cd8":null,"cd22":"","cd1":"58419781d1114d09ac0c5b3908e3c8a0","cd146":"16037","cd66":"Search","cd5":"Seattle","ab_assignments":{"RE_WEB_SRP_ZILLOWAPPLICATIONSBADGE":"CONTROL","SP_SEARCH_PAGE_SSR":"VIA_SHOPPER_PLATFORM","SP_NATIVE_FOR_RENT_PAGE":"CONTROL","ANDROID_SEMANTIC_SEARCH":"ON_PILOT_V1","VL_COST_OF_RENTING_SUMMARY":"ON","CW_HIGH_INTENT_PHONE_DESKTOP":"CONTROL","SAT_AC_NLS_RANKING":"CONTROL","SP_PAID_BUILDER_PAGE":"VIA_SHOPPER_PLATFORM","IOS_PHOTO_GALLERY_CTA":"CONTROL_OFF","VL_COST_OF_RENTING_CALCULATOR":"ON","ZHL_HDP_CHIP_PERSONALIZE_PAYMENT_CTAS":"CONTROL","SP_NATIVE_FOR_SALE_PAGE":"VIA_SHOPPER_PLATFORM","ANDROID_YOUR_ZILLOW_HOME_LOANS":"ON","AR_CSAT_ONSITE_HDP":"CONTROL","ANDROID_NATIVE_CONTACT_FORM":"CONTROL","REALTIME_PERS_MODEL_PRE":"MODEL_C_3","ARCS_IB_CONTACT_UNIFICATION":"CONTROL","ANDROID_SH_TOUR_CTA":"SH_TOUR_CTA","AB_DASHBOARD_AA_TEST":"CONTROL","RE_SECOND_BOOST":"SLOT_4","SP_NATIVE_PBHDP_PAGE":"CONTROL","ONSITE_MESSAGE_VALVE":"OMP_ON","IOS_NATIVE_CONTACT_FORM":"CONTROL","REALTIME_PERS_MODEL_MOB":"MODEL_B_3","AIPERS_ZILLOW_WEB_HOME_PAGE_COLLECTIONS":"HOMEPG_B","SP_BUILDING_PAGE":"VIA_SHOPPER_PLATFORM","SXP_MONTHLY_COST_FILTER_MVP":"ON_WITH_BADGE","ZEXP_DECISION_TOKEN_HOLD":"U2aJKT_1684435414","IOS_SH_TOUR_CTA":"CONTROL","TAS_DIRECT_CONNECT_ELIGIBLE_WEB":"ON","TAS_DIRECT_CONNECT_ELIGIBLE_ANDROID":"ON","DXP_PHOTO_CAROUSEL":"ON","SP_FOR_RENT_PAGE":"CONTROL","ARCS_IB_TOUR_UPGRADE_WEB":"CONTROL","SP_FOR_SALE_PAGE":"CONTROL","DXP_FOR_YOU":"CONTROL"},"cd7":null,"cd25":"Phone","cd197":"[2057630662, 2061283216, 2062273480, 2081470225, 2095129781, 2068397820, 2091746035, 2065519201, 2061658577, 2066753130, 2057751727, 2057683573, 2058076261, 2058009870, 2057966403, 2085085119, 2057671155, 2063138318, 2057898647, 2070449778, 2115768909, 2067041940, 2095821537, 2066477133, 2057632120, 2069792305, 2060708232, 2084653748, 2083546312, 2058283590, 2066714842, 2087063850, 2083287281, 2062163857, 2086920704, 2083761236, 2068196188, 2058015409, 2057722728, 2064129552]","seo_assignments":{"SEOTEST__RE_Add_BuildingOverview_SRP":"CONTROL","SEOTEST__SRP_PAGINATION":"CONTROL"},"cd3":"WA","cd23":"ForRent","cd12":"Unrecognized","cd4":"King County","cd158":"USER","cd159":"","cd18":"Region-City","cd71":"priorityscore","cd69":null,"cd68":"https://www.zillow.com/seattle-wa/rentals/"})}
#         catch (e) {if (isDbg) {console.error(e); }}
#         return {};
#     }
#     var _aid='58419781-d111-4d09-ac0c-5b3908e3c8a0';
#     var _uid='';
#     var _host='e.zg-api.com:443';
#     var _key='z_prod';
#     var _pn='Search:RealEstateSearch:List:SPT:FR';
#     var _rid='CWdNYkTNQ4yv_E1YuH3inQ';
#     var _adbg=false;
#     var secure=true;
#     var dim=safeDim(_adbg);
#     dim.requestId = _rid;
#     dim.name = _pn;
#
#     function zaload(w,d,ns,cdn,opt,ml,fa,my,fst){
#     w['ZillowAnalyticsObject']=ns;w[ns]=w[ns]||[];
#     if(w[ns].initialize||w[ns].invoked)return;
#     w[ns].invoked=1;w[ns]._loadOptions=opt;
#     ml=['identify','track','page','off','on','use','unuse','setdim','event','send','dwell','dwellEnd'];
#     fa=function(m){return function(){w[ns].push([].concat(m,[].slice.call(arguments)));return w[ns]}};
#     ml.forEach(function(mn){w[ns][mn]=fa(mn)});
#     if (!window['disable-analytics']) {
#         my=d.createElement('script');fst=d.getElementsByTagName('script')[0];
#
#             my.defer=!0;my.src=cdn;if(fst)fst.parentNode.insertBefore(my,fst);
#
#
#         return w[ns];
#     }
#     };
#
#     zaload(window,document,'zanalytics', 'https://e.zg-api.com/a/z/js/v1/analytics.js?v=bcf290c', {'zillow': {
#         apiKey: _key,
#         apiHost: _host,
#         secure: secure,
#         anonymousId: _aid,
#         dimensions: dim,
#     }});
#
#     if (_uid) { zanalytics.identify(_uid); }  else { zanalytics.identify(null); }
# })();
# /* Queue for Global UA Object */
# (function(w,n){w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments)}})(window, 'ua');
#    </script>
#    <noscript>
#     <img alt="" height="0" src="https://sb.scorecardresearch.com/b2?c1=2&amp;c2=6036206&amp;c3=&amp;c4=www.zillow.com/seattle-wa/rentals/&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" style="display:none" width="0"/>
#    </noscript>
#   </div>
#   <script>
#    window.zBodyScripts=(function(){if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script request start")}if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script callback start")}window.addEventListener("DOMContentLoaded",function(){if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("dom ready");window.ClientProfiler.profile("dom ready complete")}});(function(){ga("require","ec")}());if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script callback end")}if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script request end")}});window.lifecycleQueue.addCallbackToEvent(window.zBodyScripts,"priorityUIReady");
#   </script>
#   <script>
#    lifecycleQueue.addScriptToEvent('https://s.zillowstatic.com/s3/pfs/oneTrust-8fea850986e769e47360.js', 'priorityUIReady');
#                 lifecycleQueue.addScriptToEvent('https://s.zillowstatic.com/s3/pfs/reg-6fea00a7c7b09dc34778.js', 'priorityUIReady');
#   </script>
#   <script>
#    (function(){var m="add_",p="handler",j=p+"s",c="_"+p,a=m+p,f="invalid_field"+c,x="find",l="form",s="abort",i="value",b="events",e="cancel",r=e+"_"+j,g="on",y="submit",w=g+y,o="pre"+y,q="post"+y,t=y+"mode",h=y+"name",u="refresh",n="reset",z="";var k={FORM_NOT_FOUND:{},default_invalid_field_handler:function(B,C,A){if(!B[s]&&!C.disabled){this.set_focus(C);window.alert(A);B[s]=true;B[r]=true}},find:function(A){return document.getElementById(A)},register_form:function(B){var A=this[x](B);if(!A){this.FORM_NOT_FOUND[B]=true;return}A[b]=new d(A)},onpresubmit:function(C,A){var B=this[x](C);B[b][m+o+c](A)},onsubmit:function(B,A){this[x](B)[b][m+y+c](A)},onpostsubmit:function(B,A){this[x](B)[b][m+q+c](A)},onreset:function(B,A){this[x](B)[b][m+n+c](A)},onrefresh:function(B,A){this[x](B)[b][m+u+c](A)},oncancel:function(B,A){this[x](B)[b][m+e+c](A)},set_focus:function(A){if(typeof A==="string"){A=this[x](A);if(A){if(!A.disabled&&A.style.visibility!=="hidden"&&A.style.display!=="none"&&A.clientWidth>0){if(A.focus){A.focus()}if(A.isContentEditable||A.isContentEditable===undefined){if(A.select){A.select()}}}}}},trim_field_value:function(A){var B=this[x](A);B[i]=B[i].replace(/^\s+/g,"").replace(/\s+$/g,"")},require_field:function(C,A,B){var D=this[x](A);if(D[i].length===0){C.invalid_field(D,B)}},submit_form:function(A,B){this[x](A)[b][y](B)}};function v(C,B,A){this[l]=C;this.type=B;this[s]=false;this[r]=false;this[f]=A}v.prototype={invalid_field:function(B,A){this[f].call(k,this,B,A)},toString:function(){return"FormSubmitEvent["+this[l].name+" "+this.type+" "+this[s]+"]"}};function d(A){var B=this;B[l]=A;B.handlers={};A.onsubmit=function(){return A[b].onsubmit_handler()};A.onreset=function(){return A[b].onreset_handler()};B[f]=k.default_invalid_field_handler}d.prototype={add_handler:function(B,A){var C=this.handlers[B];if(!C){C=[];this.handlers[B]=C}C.push(A)},invoke_handlers:function(B,D){if(D[r]){return}var E=this.handlers[B];if(!E){return}var C=E.length,A=0;for(;A<C;A++){E[A].call(window,D);if(D[r]){return}}},add_cancel_handler:function(A){this[a](e,A)},cancel:function(){var C=this,B=C[l],A=new v(B,e,C[f]);C.invoke_handlers(e,A);if(A[s]===false){B[t][i]=e;B[w]=null;B[y]()}},add_presubmit_handler:function(A){this[a](o,A)},add_submit_handler:function(A){this[a](y,A)},add_postsubmit_handler:function(A){this[a](q,A)},submit:function(A){var C=this,B=C[l];if(C.onsubmit_handler()){B[w]=null;B[h][i]=A;B[y]()}},onsubmit_handler:function(){var C=this,B=C[l],A=new v(B,y,C[f]);C.invoke_handlers(o,A);C.invoke_handlers(y,A);C.invoke_handlers(q,A);if(A[s]){return false}B[t][i]=y;B[h][i]=z;return true},add_refresh_handler:function(A){this[a](y,A);this[a](u,A)},refresh:function(A){var D=this,C=D[l],B=new v(C,u,D[f]);D.invoke_handlers(u,B);if(B[s]){return}C[t][i]=u;C[h][i]=A;C[w]=null;C[y]()},add_reset_handler:function(A){this[a](n,A)},onreset_handler:function(){var B=this,A=new v(B[l],n,B[f]);B.invoke_handlers(n,A);return !A[s]}};this.Tapestry=k}());
#   </script>
#   <script language="JavaScript" type="text/javascript">
#    <!--
# if(!window.ZMOB_nativeAPI||(window.ZMOB_nativeAPI&&!window.ZMOB_nativeAPI.trackWebviewEvent)){(function(){window._gaq=window._gaq||[];window._gaqBackup=window._gaqBackup||[];window._gaq.push(["_setAccount","UA-21174015-1"]);window._gaq.push(["_setDomainName",".zillow.com"]);window._gaqBackup=[["_setCustomVar",6,"Zip",""],["_setCustomVar",8,"Address",""],["_setCustomVar",22,"AccountCreationDate","",1],["_setCustomVar",1,"Guid","58419781d1114d09ac0c5b3908e3c8a0",1],["_setCustomVar",146,"RegionID","16037"],["_setCustomVar",66,"PageType","Search"],["_setCustomVar",5,"City","Seattle"],["_setCustomVar",165,"A/B Test 27","RE_WEB_SRP_ZILLOWAPPLICATIONSBADGE.CONTROL",1],["_setCustomVar",7,"Neighborhood",""],["_setCustomVar",168,"A/B Test 30","SP_SEARCH_PAGE_SSR.VIA_SHOPPER_PLATFORM",1],["_setCustomVar",169,"A/B Test 31","SP_NATIVE_FOR_RENT_PAGE.CONTROL",1],["_setCustomVar",25,"Device Type","Phone"],["_setCustomVar",197,"searchListZpids","[2057630662, 2061283216, 2062273480, 2081470225, 2095129781, 2068397820, 2091746035, 2065519201, 2061658577, 2066753130, 2057751727, 2057683573, 2058076261, 2058009870, 2057966403, 2085085119, 2057671155, 2063138318, 2057898647, 2070449778, 2115768909, 2067041940, 2095821537, 2066477133, 2057632120, 2069792305, 2060708232, 2084653748, 2083546312, 2058283590, 2066714842, 2087063850, 2083287281, 2062163857, 2086920704, 2083761236, 2068196188, 2058015409, 2057722728, 2064129552]"],["_setCustomVar",166,"A/B Test 28","ANDROID_SEMANTIC_SEARCH.ON_PILOT_V1",1],["_setCustomVar",167,"A/B Test 29","VL_COST_OF_RENTING_SUMMARY.ON",1],["_setCustomVar",92,"SEO Test 3","SEOTEST__RE_Add_BuildingOverview_SRP.CONTROL",1],["_setCustomVar",3,"State","WA"],["_setCustomVar",90,"SEO Test 1","SEOTEST__SRP_PAGINATION.CONTROL",1],["_setCustomVar",23,"SearchTypes","ForRent",2],["_setCustomVar",12,"UserType","Unrecognized",2],["_setCustomVar",60,"A/B Test 20","CW_HIGH_INTENT_PHONE_DESKTOP.CONTROL",1],["_setCustomVar",171,"A/B Test 33","SAT_AC_NLS_RANKING.CONTROL",1],["_setCustomVar",172,"A/B Test 34","SP_PAID_BUILDER_PAGE.VIA_SHOPPER_PLATFORM",1],["_setCustomVar",170,"A/B Test 32","IOS_PHOTO_GALLERY_CTA.CONTROL_OFF",1],["_setCustomVar",175,"A/B Test 37","VL_COST_OF_RENTING_CALCULATOR.ON",1],["_setCustomVar",4,"County","King County"],["_setCustomVar",176,"A/B Test 38","ZHL_HDP_CHIP_PERSONALIZE_PAYMENT_CTAS.CONTROL",1],["_setCustomVar",173,"A/B Test 35","SP_NATIVE_FOR_SALE_PAGE.VIA_SHOPPER_PLATFORM",1],["_setCustomVar",174,"A/B Test 36","ANDROID_YOUR_ZILLOW_HOME_LOANS.ON",1],["_setCustomVar",179,"A/B Test 41","AR_CSAT_ONSITE_HDP.CONTROL",1],["_setCustomVar",177,"A/B Test 39","ANDROID_NATIVE_CONTACT_FORM.CONTROL",1],["_setCustomVar",178,"A/B Test 40","REALTIME_PERS_MODEL_PRE.MODEL_C_3",1],["_setCustomVar",40,"A/B Test 15","ARCS_IB_CONTACT_UNIFICATION.CONTROL",1],["_setCustomVar",57,"A/B Test 17","ANDROID_SH_TOUR_CTA.SH_TOUR_CTA",1],["_setCustomVar",50,"A/B Test 10","AB_DASHBOARD_AA_TEST.CONTROL",1],["_setCustomVar",158,"RegionTrialType","USER"],["_setCustomVar",182,"A/B Test 44","RE_SECOND_BOOST.SLOT_4",1],["_setCustomVar",183,"A/B Test 45","SP_NATIVE_PBHDP_PAGE.CONTROL",1],["_setCustomVar",180,"A/B Test 42","ONSITE_MESSAGE_VALVE.OMP_ON",1],["_setCustomVar",159,"UserFirstVisitTrialTypes",""],["_setCustomVar",181,"A/B Test 43","IOS_NATIVE_CONTACT_FORM.CONTROL",1],["_setCustomVar",18,"SearchScenario","Region-City"],["_setCustomVar",186,"A/B Test 48","REALTIME_PERS_MODEL_MOB.MODEL_B_3",1],["_setCustomVar",187,"A/B Test 49","AIPERS_ZILLOW_WEB_HOME_PAGE_COLLECTIONS.HOMEPG_B",1],["_setCustomVar",184,"A/B Test 46","SP_BUILDING_PAGE.VIA_SHOPPER_PLATFORM",1],["_setCustomVar",185,"A/B Test 47","SXP_MONTHLY_COST_FILTER_MVP.ON_WITH_BADGE",1],["_setCustomVar",71,"SortType","priorityscore"],["_setCustomVar",188,"A/B Test 50","ZEXP_DECISION_TOKEN_HOLD.U2aJKT_1684435414",1],["_setCustomVar",69,"FullReferringURL",""],["_setCustomVar",49,"A/B Test 9","IOS_SH_TOUR_CTA.CONTROL",1],["_setCustomVar",65,"A/B Test 25","TAS_DIRECT_CONNECT_ELIGIBLE_WEB.ON",1] ...
# var _comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/seattle-wa/rentals/",c5:"",c6:"",c15:"",options:{url_append:"comscorekw=rentals"}});var _comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);
#
# // -->
#   </script>
#  </body>
# </html>
# <!-- H:031  T:371ms  S:659586  R:Thu May 18 11:43:34 PDT 2023  B:5.0.70311-master.405e64c~qa,spring_4_pre.f52f536a -->

# %%
def parse_search_pages(soup_list: list) -> list:
    apartment_info = []

    def get_API_request_tag(soup: object) -> str:
        API_request_tag = soup.find(
            "script",
            {
                "data-zrr-shared-data-key": "mobileSearchPageStore",
                "type": "application/json",
            },
        )
        return API_request_tag

    def parse_API_request_tag(API_request_tag: str) -> dict:
        """Parse the API request tag into a python dictionary.

        The API request tag is a script tag that contains a python dictionary.  The python dictionary contains multiple dictionaries.  The list_results dictionary contains the apartment information.

        Exceptions:
           If the API request tag is not found, return an empty dictionary."""
        try:
            json_API_request_tag = API_request_tag.text.replace(
                "<!--", ""
            ).replace("-->", "")
            API_request_dict = json.loads(json_API_request_tag)
            return API_request_dict
        except:
            pass

    def get_listing_results(API_request_dict: dict) -> list:
        """Find the list_results in the API request dictionary.

        The list_results contains the apartment information.

        Exceptions:
            If the list_results is not found, return an empty list."""
        listing_results = []
        try:
            for key, value in API_request_dict.items():
                if key == "cat1":
                    for key, value in value.items():
                        if key == "searchResults":
                            for key, value in value.items():
                                if key == "listResults":
                                    for listing in value:
                                        listing_results.append(listing)
            return listing_results
        except:
            pass

    # find the list_results json object for each soup in soup_list (contains the apartment information)
    for soup in soup_list:
        API_request_tag = get_API_request_tag(soup)
        API_request_dict = parse_API_request_tag(API_request_tag)
        listing_results = get_listing_results(API_request_dict)
        apartment_info.append(listing_results)
    return apartment_info


apartment_info = parse_search_pages(soup_list)
apartment_info_json = json.dumps(apartment_info)

# %%
import sys

print(sys.path)
sys.path.append(
    "C:/python-projects/zillow_webscraper/issues/zillow-webscraper/data"
)
# Out:
# ['c:\\python-projects\\zillow_webscraper\\issues\\zillow-webscraper\\notebooks', 'C:\\Users\\work\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'C:\\Users\\work\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'C:\\Users\\work\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\Users\\work\\AppData\\Local\\Programs\\Python\\Python310', 'c:\\pythonvenv\\web_scraping', '', 'c:\\pythonvenv\\web_scraping\\lib\\site-packages', 'c:\\pythonvenv\\web_scraping\\lib\\site-packages\\win32', 'c:\\pythonvenv\\web_scraping\\lib\\site-packages\\win32\\lib', 'c:\\pythonvenv\\web_scraping\\lib\\site-packages\\Pythonwin']

# %%
with open(
    "C:/python-projects/zillow_webscraper/issues/zillow-webscraper/data/raw_v2/raw_search_info_2",
    "w",
) as f:
    f.write(apartment_info_json)
