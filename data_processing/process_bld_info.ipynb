# %%
import json

with open('C:/Projects/Housing_Price_Prediction/data_processing/raw_bld_info.json', 'r') as f:
    bld_info_list = json.loads(f.read())

# %% [markdown]
# ### parse the following keys:
# -	address
# -	floorPlans
# -	buildingAttributes
# -	amenitySummary
# -	assignedSchools
# -	walkScore
# -	transitScore
# -	bikeScore
# -	amenityDetails
# -	detailedPetPolicy

# %%
def clean_address(address_dict):    
    '''fixes the address of the address dictionary of each building dictionary
    '''
    try:
        address = ""
        for key, value in address_dict.items():
            if key != '__typename' and key != 'neighborhood':
                address = address + value + " "
        return address[0:-2]
    except AttributeError as e:
        print("building address is the wrong format or is already parsed")

# %%
def clean_floorPlans(building_info_dict):
    '''make new entries for each unit in each plan of the different floor plans
    '''
    try:
        # iterate through each floor plan (dictionary) in the building's floor plan list
        for floor_plan_dict in building_info_dict['floorPlans']:
            
            
            # iterate through the key, value pairs in the floor plan dictionary
            for key, value in floor_plan_dict.items():

                # check if the key is the 'units' key
                if key == 'units':
                    units_list = value

                    # iterate through each unit in the units list of each floor plan of each building
                    for unit in units_list:
                        
                        # iterate through each attribute of each unit
                        for key, value in units.items():
                            
    except AttributeError as e:
        print("listing floorPlans is the wrong format or is already parsed")

# %%
floor_plans_list = []
for bld_info_dict in bld_info_list:
    print(json.dumps(bld_info_dict, indent=5))
    for floor_plans in bld_info_dict['floorPlans']:
        floor_plans_list.append(floor_plans)

units_list = []
for floor_plan in floor_plans_list:
    for key, value in floor_plan.items():
        if key == 'units':
            for unit in value:
                units_list.append(unit)
#print(json.dumps(units_list, indent=5))
# Out:
# {
#      "buildingName": "ArtHouse",
#      "latitude": 47.612848,
#      "longitude": -122.348938,
#      "lotId": "1008623254",
#      "address": {
#           "streetAddress": "2334 Elliott Ave",
#           "city": "Seattle",
#           "state": "WA",
#           "zipcode": "98121",
#           "__typename": "Address",
#           "neighborhood": null
#      },
#      "zipcode": "98121",
#      "isLandlordLiaisonProgram": false,
#      "buildingType": "FOR_RENT",
#      "listingFeatureType": "featured-ppc",
#      "photoCount": 35,
#      "videos": [],
#      "floorPlans": [
#           {
#                "zpid": "2077853997",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 712",
#                          "zpid": "2077853997",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681801200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 1632,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 612",
#                          "zpid": "2069514953",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1684479600000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 1676,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 812",
#                          "zpid": "2073870646",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1684479600000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 1725,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 714",
#                          "zpid": "2078922367",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1683615600000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 1735,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 1632,
#                "maxPrice": 1735,
#                "availableFrom": "1681801200000",
#                "baths": 1,
#                "beds": 0,
#                "floorPlanUnitPhotos": [],
#                "name": "Studio - C & D",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/4665505c2d47cb05102f58258adcb680-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/4665505c2d47cb05102f58258adcb680-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 498,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": null
#           },
#           {
#                "zpid": "2058275652",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 409",
#                          "zpid": "2058275652",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1683788400000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2017,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2017,
#                "maxPrice": 2017,
#                "availableFrom": "1683788400000",
#                "baths": 1,
#                "beds": 1,
#                "floorPlanUnitPhotos": [],
#                "name": "I",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/047ff6859c26562b4f73f0448a1f41e9-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/047ff6859c26562b4f73f0448a1f41e9-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 724,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "1 Bedroom 1 Bath - I"
#           },
#           {
#                "zpid": "2073360208",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 811",
#                          "zpid": "2073360208",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1688713200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2345,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2345,
#                "maxPrice": 2345,
#                "availableFrom": "1688713200000",
#                "baths": 1,
#                "beds": 1,
#                "floorPlanUnitPhotos": [],
#                "name": "F",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/421df44f6d1bb1480ac4a346268a8149-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/421df44f6d1bb1480ac4a346268a8149-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 665,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Open 1 Bed 1 Bath - F"
#           }
#      ],
#      "buildingAttributes": {
#           "hasSharedLaundry": false,
#           "airConditioning": "Unknown",
#           "appliances": [
#                "Washer",
#                "Dryer"
#           ],
#           "parkingTypes": [
#                "ParkingLot"
#           ],
#           "detailedParkingPolicies": [
#                {
#                     "parkingType": "surfaceLot",
#                     "__typename": "DetailedParkingPolicy",
#                     "assigned": null,
#                     "comment": null,
#                     "numberOfSpaces": null,
#                     "spaceFee": null
#                },
#                {
#                     "parkingType": "other",
#                     "__typename": "DetailedParkingPolicy",
#                     "assigned": null,
#                     "comment": null,
#                     "numberOfSpaces": null,
#                     "spaceFee": null
#                }
#           ],
#           "outdoorCommonAreas": [
#                "Patio"
#           ],
#           "hasBarbecue": null,
#           "heatingSource": "Unknown",
#           "detailedPetPolicy": {
#                "general": null,
#                "petPolicies": [
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": null,
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": null,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": null,
#                          "petType": "cats",
#                          "restriction": null
#                     },
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": null,
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": null,
#                          "maxWeightAllowed": 75,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": null,
#                          "petType": "dogs",
#                          "restriction": "Breed Restrictions Apply"
#                     }
#                ],
#                "__typename": "DetailedPetPolicy"
#           },
#           "petPolicies": [
#                "Cats",
#                "SmallDogs",
#                "LargeDogs"
#           ],
#           "hasElevator": null,
#           "__typename": "BuildingAttributes",
#           "communityRooms": [
#                "Unknown"
#           ],
#           "sportsCourts": [
#                "Unknown"
#           ],
#           "hasBicycleStorage": null,
#           "hasGuestSuite": null,
#           "hasStorage": null,
#           "hasPetPark": null,
#           "hasTwentyFourHourMaintenance": null,
#           "hasDryCleaningDropOff": null,
#           "hasOnlineRentPayment": null,
#           "hasOnlineMaintenancePortal": null,
#           "hasOnsiteManagement": null,
#           "hasPackageService": null,
#           "hasValetTrash": null,
#           "hasSpanishSpeakingStaff": null,
#           "securityTypes": [
#                "Unknown"
#           ],
#           "viewType": [
#                "Unknown"
#           ],
#           "hasHotTub": null,
#           "hasSauna": null,
#           "hasSwimmingPool": null,
#           "hasAssistedLiving": false,
#           "hasDisabledAccess": null,
#           "floorCoverings": [
#                "Unknown"
#           ],
#           "communicationTypes": [
#                "Unknown"
#           ],
#           "hasCeilingFan": null,
#           "hasFireplace": null,
#           "hasPatioBalcony": true,
#           "isFurnished": null,
#           "customAmenities": "A Myriad of Thoughtful Floor Plans?Chic Chef Kitchens with Contemporary Cabinetry?Expansive Floor-To-Ceiling Windows?Stunning Views of Puget Sound?USB Charging Stations?Walk-in Closets*",
#           "parkingDescription": null,
#           "petPolicyDescription": null,
#           "parkingRentDescription": null,
#           "isSmokeFree": null,
#           "applicationFee": null,
#           "administrativeFee": null,
#           "depositFeeMin": null,
#           "depositFeeMax": null,
#           "leaseTerms": [
#                "Unknown"
#           ],
#           "utilitiesIncluded": [
#                "Unknown"
#           ],
#           "leaseLengths": null
#      },
#      "amenitySummary": {
#           "buildingDetails": null,
#           "__typename": "AmenitySummary",
#           "laundry": [
#                "Washer/dryer"
#           ]
#      },
#      "isLowIncome": false,
#      "isSeniorHousing": false,
#      "isStudentHousing": false,
#      "screeningCriteria": null,
#      "assignedSchools": [
#           {
#                "distance": 1.7,
#                "name": "Lowell Elementary School",
#                "rating": 8,
#                "level": "PRE_K,ELEMENTARY",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "PK-5",
#                "link": "https://www.greatschools.org/school?id=5301580&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 2.2,
#                "name": "Edmonds S. Meany Middle School",
#                "rating": 5,
#                "level": "MIDDLE",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "6-8",
#                "link": "https://www.greatschools.org/school?id=5307459&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 2.3,
#                "name": "Garfield High School",
#                "rating": 7,
#                "level": "HIGH",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "9-12",
#                "link": "https://www.greatschools.org/school?id=5301561&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           }
#      ],
#      "nearbyAmenities": [],
#      "walkScore": {
#           "walkscore": 96,
#           "description": "Walker's Paradise",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.6128/lng=-122.3489/?utm_source=zillow2.com&utm_medium=ws_api&utm_campaign=ws_api",
#           "__typename": "WalkScoreResponse"
#      },
#      "transitScore": {
#           "transit_score": 99,
#           "description": "Rider's Paradise",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.6128/lng=-122.3489/?utm_source=zillow2.com&utm_medium=ts_api&utm_campaign=ts_api",
#           "__typename": "TransitScoreResponse"
#      },
#      "bikeScore": {
#           "bikescore": 76,
#           "description": "Very Bikeable",
#           "__typename": "BikeScoreResponse"
#      },
#      "description": "Discover premier apartment living at ArtHouse, located just a block up from Seattle's stunning waterfront, where you'll fall in love with floor-to-ceiling windows, landscaped terraces, a pet-friendly patio, vibrant design on every floor and sparkling Puget Sound views around every corner.\n\nSoak in the beauty of your quintessentially PNW outdoor surroundings, where the indoors feel like walking the walls of a giant art gallery. ArtHouse offers bold, beautiful living, inside and out.",
#      "amenityDetails": {
#           "hours": [
#                "Mon - Fri: 9:00AM - 6:00PM",
#                "Sat: 10:00AM - 5:00PM",
#                "Sun: Closed"
#           ],
#           "__typename": "AmenityDetails",
#           "pets": [
#                "Cats",
#                "Large dogs",
#                "Small dogs"
#           ],
#           "petDetails": [],
#           "customAmenities": {
#                "rawAmenities": [
#                     "A Myriad of Thoughtful Floor Plans",
#                     "Chic Chef Kitchens with Contemporary Cabinetry",
#                     "Expansive Floor-To-Ceiling Windows",
#                     "Stunning Views of Puget Sound",
#                     "USB Charging Stations",
#                     "Walk-in Closets*"
#                ],
#                "__typename": "CustomAmenities"
#           },
#           "unitFeatures": [
#                "Washer/dryer",
#                "Patio/balcony"
#           ]
#      },
#      "detailedPetPolicy": {
#           "general": null,
#           "petPolicies": [
#                {
#                     "allowed": true,
#                     "comment": null,
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": null,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": false,
#                     "petSize": null,
#                     "petType": "cats",
#                     "restriction": null,
#                     "__typename": "PetPolicy"
#                },
#                {
#                     "allowed": true,
#                     "comment": null,
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": null,
#                     "maxWeightAllowed": 75,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": false,
#                     "petSize": null,
#                     "petType": "dogs",
#                     "restriction": "Breed Restrictions Apply",
#                     "__typename": "PetPolicy"
#                }
#           ],
#           "__typename": "DetailedPetPolicy"
#      }
# }
# {
#      "buildingName": "Angeline Apartments",
#      "latitude": 47.559143,
#      "longitude": -122.286748,
#      "lotId": "1134781404",
#      "address": {
#           "streetAddress": "4801 Rainier Ave S",
#           "city": "Seattle",
#           "state": "WA",
#           "zipcode": "98118",
#           "__typename": "Address",
#           "neighborhood": null
#      },
#      "zipcode": "98118",
#      "isLandlordLiaisonProgram": false,
#      "buildingType": "FOR_RENT",
#      "listingFeatureType": "featured",
#      "photoCount": 25,
#      "videos": [],
#      "floorPlans": [
#           {
#                "zpid": "2058015409",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 615-A",
#                          "zpid": "2058015409",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1684911600000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2105,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2105,
#                "maxPrice": 2105,
#                "availableFrom": "1684911600000",
#                "baths": 1,
#                "beds": 0,
#                "floorPlanUnitPhotos": [],
#                "name": "Pasilla",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/6575923598f645f5260ea20740642a7e-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/6575923598f645f5260ea20740642a7e-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 539,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2058015408",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 319-A",
#                          "zpid": "2058015408",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1686553200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2150,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 420-A",
#                          "zpid": "2058015405",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1683529200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2230,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2150,
#                "maxPrice": 2230,
#                "availableFrom": "1683529200000",
#                "baths": 1,
#                "beds": 0,
#                "floorPlanUnitPhotos": [],
#                "name": "Sage",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/1e9abb0820a5b2b341b591c1c31dc3ea-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/1e9abb0820a5b2b341b591c1c31dc3ea-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 597,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2058015407",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 209-A",
#                          "zpid": "2058015407",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681974000000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2285,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 612-A",
#                          "zpid": "2058015410",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681974000000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2435,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2285,
#                "maxPrice": 2435,
#                "availableFrom": "1681974000000",
#                "baths": 1,
#                "beds": 1,
#                "floorPlanUnitPhotos": [],
#                "name": "Thyme",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/f06eea9f57e288a66bc1f2deb049ebff-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/f06eea9f57e288a66bc1f2deb049ebff-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 690,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2057898897",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 333-A",
#                          "zpid": "2057898897",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1686466800000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2475,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 233-A",
#                          "zpid": "2058015411",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1683097200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2480,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 221-A",
#                          "zpid": "2057934325",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1685602800000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2485,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     },
#                     {
#                          "unitNumber": "Unit 421-A",
#                          "zpid": "2058015406",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1683529200000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 2495,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 2475,
#                "maxPrice": 2495,
#                "availableFrom": "1683097200000",
#                "baths": 1,
#                "beds": 1,
#                "floorPlanUnitPhotos": [],
#                "name": "Tarragon",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/075d4b5a369d66d4d3c6e947c797fec2-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/075d4b5a369d66d4d3c6e947c797fec2-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 777,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2058015413",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 211-A",
#                          "zpid": "2058015413",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1682924400000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 3440,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 3440,
#                "maxPrice": 3440,
#                "availableFrom": "1682924400000",
#                "baths": 2,
#                "beds": 2,
#                "floorPlanUnitPhotos": [
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/c589f3e69cca141661a449984d11e998-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/d866f0f9f236664538320fef3966d0f5-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/3175d6bc4a944a3c35d57c33f90374f1-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/9ab0f2dad688d5b455bcc06df2de8cbd-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/576bfcecb9dccbe1c682fcd40ef1b5c7-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/5de76aa99fdcb99dbf4a53f2f5ac9dd6-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/80fc293994b602966720480d7eab802c-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/43d6a22a11bb367ac9f3ff1014d6c851-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/a109e81e58d91f7e9399fd095cf83dcc-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/5f7857cca6ff76832a9ce8de479e343e-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/1339e924fe814ff941bd95b0c7a234e5-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/add60e8d248e6cd83b1e6888075627bc-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "name": "Turmeric",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/cd559ace26da6debecbc48ec2b557a5c-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/cd559ace26da6debecbc48ec2b557a5c-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 1138,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2058015414",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 510-A",
#                          "zpid": "2058015414",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681974000000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 3480,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 3480,
#                "maxPrice": 3480,
#                "availableFrom": "1681974000000",
#                "baths": 2,
#                "beds": 2,
#                "floorPlanUnitPhotos": [],
#                "name": "Mignonette",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/a5cde1cf504b747c9e1a2a2783e0d9c1-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/a5cde1cf504b747c9e1a2a2783e0d9c1-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 1046,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           },
#           {
#                "zpid": "2058015404",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 428-A",
#                          "zpid": "2058015404",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681974000000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 3605,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 3605,
#                "maxPrice": 3605,
#                "availableFrom": "1681974000000",
#                "baths": 2,
#                "beds": 2,
#                "floorPlanUnitPhotos": [],
#                "name": "Saffron",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/101c2a94f3b8caad1621ef30c25e534c-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/101c2a94f3b8caad1621ef30c25e534c-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 1233,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "Smoking allowed:No"
#           }
#      ],
#      "buildingAttributes": {
#           "hasSharedLaundry": false,
#           "airConditioning": "Yes",
#           "appliances": [
#                "Washer",
#                "Dryer"
#           ],
#           "parkingTypes": [
#                "Unknown"
#           ],
#           "detailedParkingPolicies": null,
#           "outdoorCommonAreas": [
#                "Deck",
#                "Garden"
#           ],
#           "hasBarbecue": null,
#           "heatingSource": "Unknown",
#           "detailedPetPolicy": {
#                "general": null,
#                "petPolicies": [
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": "Pets Allowed",
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": 2,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": null,
#                          "petType": "dogs",
#                          "restriction": "For complete Breed Restrictions, please see the Important Links section on our website."
#                     },
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": "Pets Allowed",
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": 2,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": null,
#                          "petType": "cats",
#                          "restriction": "For complete Breed Restrictions, please see the Important Links section on our website."
#                     }
#                ],
#                "__typename": "DetailedPetPolicy"
#           },
#           "petPolicies": [
#                "Cats",
#                "SmallDogs"
#           ],
#           "hasElevator": true,
#           "__typename": "BuildingAttributes",
#           "communityRooms": [
#                "Clubhouse",
#                "ConferenceRoom",
#                "FitnessCenter",
#                "Lounge",
#                "PetWashingStation"
#           ],
#           "sportsCourts": [
#                "Unknown"
#           ],
#           "hasBicycleStorage": true,
#           "hasGuestSuite": null,
#           "hasStorage": true,
#           "hasPetPark": null,
#           "hasTwentyFourHourMaintenance": null,
#           "hasDryCleaningDropOff": null,
#           "hasOnlineRentPayment": null,
#           "hasOnlineMaintenancePortal": null,
#           "hasOnsiteManagement": true,
#           "hasPackageService": true,
#           "hasValetTrash": null,
#           "hasSpanishSpeakingStaff": null,
#           "securityTypes": [
#                "GatedEntry",
#                "Intercom"
#           ],
#           "viewType": [
#                "Unknown"
#           ],
#           "hasHotTub": null,
#           "hasSauna": null,
#           "hasSwimmingPool": null,
#           "hasAssistedLiving": false,
#           "hasDisabledAccess": true,
#           "floorCoverings": [
#                "Unknown"
#           ],
#           "communicationTypes": [
#                "Unknown"
#           ],
#           "hasCeilingFan": null,
#           "hasFireplace": null,
#           "hasPatioBalcony": null,
#           "isFurnished": null,
#           "customAmenities": "Cinema Room?Community Wifi?Pedal Club?Picnic/bbq Area?Terrace?City View - Partial?Condo-Quality Fixtures?Corner Unit?Custom Cabinetry?Energy Star Stainless Steel Appliances?Fl3?Fl4?Fl5?Fl6?Flt1?Lake View?Luxury Hardwood-Look Flooring?Private Outdoor Space?Quartz Kitchen Courtertops?Spacious Closets?V",
#           "parkingDescription": null,
#           "petPolicyDescription": null,
#           "parkingRentDescription": null,
#           "isSmokeFree": true,
#           "applicationFee": 24,
#           "administrativeFee": null,
#           "depositFeeMin": null,
#           "depositFeeMax": null,
#           "leaseTerms": [
#                "Unknown"
#           ],
#           "utilitiesIncluded": [
#                "Unknown"
#           ],
#           "leaseLengths": null
#      },
#      "amenitySummary": {
#           "buildingDetails": null,
#           "__typename": "AmenitySummary",
#           "laundry": [
#                "Washer/dryer"
#           ]
#      },
#      "isLowIncome": false,
#      "isSeniorHousing": false,
#      "isStudentHousing": false,
#      "screeningCriteria": null,
#      "assignedSchools": [
#           {
#                "distance": 0.5,
#                "name": "Hawthorne Elementary School",
#                "rating": 5,
#                "level": "PRE_K,ELEMENTARY",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "PK-5",
#                "link": "https://www.greatschools.org/school?id=5301639&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 1.3,
#                "name": "Mercer Middle School",
#                "rating": 8,
#                "level": "MIDDLE",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "6-8",
#                "link": "https://www.greatschools.org/school?id=5301541&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 1.3,
#                "name": "Franklin High School",
#                "rating": 4,
#                "level": "HIGH",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "9-12",
#                "link": "https://www.greatschools.org/school?id=5301559&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           }
#      ],
#      "nearbyAmenities": [],
#      "walkScore": {
#           "walkscore": 94,
#           "description": "Walker's Paradise",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.5591/lng=-122.2867/?utm_source=zillow2.com&utm_medium=ws_api&utm_campaign=ws_api",
#           "__typename": "WalkScoreResponse"
#      },
#      "transitScore": {
#           "transit_score": 62,
#           "description": "Good Transit",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.5591/lng=-122.2867/?utm_source=zillow2.com&utm_medium=ts_api&utm_campaign=ts_api",
#           "__typename": "TransitScoreResponse"
#      },
#      "bikeScore": {
#           "bikescore": 84,
#           "description": "Very Bikeable",
#           "__typename": "BikeScoreResponse"
#      },
#      "description": "Embrace the Seattle lifestyle at Angeline Apartments. Experience a world of cultures, traditions, ethnicities, and customs. At Angeline, you're a part of the vibrant, rich community of historic Columbia City. Boasting a walk score of 95, our location around the corner from the neighborhood business district can't be beat. We're a 7-minute walk to the light rail, which zips to Downtown Seattle in just 15 minutes. The beach at Seward Park is a 10-minute drive away.",
#      "amenityDetails": {
#           "hours": [
#                "Mon - Fri: 9:00AM - 6:00PM",
#                "Sat: 10:00AM - 5:00PM",
#                "Sun: 11:00AM - 5:00PM"
#           ],
#           "__typename": "AmenityDetails",
#           "pets": [
#                "Cats",
#                "Small dogs"
#           ],
#           "petDetails": [],
#           "customAmenities": {
#                "rawAmenities": [
#                     "Cinema Room",
#                     "Community Wifi",
#                     "Pedal Club",
#                     "Picnic/bbq Area",
#                     "Terrace",
#                     "City View - Partial",
#                     "Condo-Quality Fixtures",
#                     "Corner Unit",
#                     "Custom Cabinetry",
#                     "Energy Star Stainless Steel Appliances",
#                     "Fl3",
#                     "Fl4",
#                     "Fl5",
#                     "Fl6",
#                     "Flt1",
#                     "Lake View",
#                     "Luxury Hardwood-Look Flooring",
#                     "Private Outdoor Space",
#                     "Quartz Kitchen Courtertops",
#                     "Spacious Closets",
#                     "V"
#                ],
#                "__typename": "CustomAmenities"
#           },
#           "unitFeatures": [
#                "Washer/dryer",
#                "Air conditioning"
#           ]
#      },
#      "detailedPetPolicy": {
#           "general": null,
#           "petPolicies": [
#                {
#                     "allowed": true,
#                     "comment": "Pets Allowed",
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": 2,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": null,
#                     "petSize": null,
#                     "petType": "dogs",
#                     "restriction": "For complete Breed Restrictions, please see the Important Links section on our website.",
#                     "__typename": "PetPolicy"
#                },
#                {
#                     "allowed": true,
#                     "comment": "Pets Allowed",
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": 2,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": null,
#                     "petSize": null,
#                     "petType": "cats",
# ...
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/b837c8d966b995237bda430e1bbdab76-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 817,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "12 months"
#           },
#           {
#                "zpid": "2073354011",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 201",
#                          "zpid": "2073354011",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1682060400000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 3495,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 3495,
#                "maxPrice": 3495,
#                "availableFrom": "1682060400000",
#                "baths": 2,
#                "beds": 2,
#                "floorPlanUnitPhotos": [],
#                "name": "2x2E",
#                "photos": null,
#                "sqft": 1053,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "12 months"
#           },
#           {
#                "zpid": "2061645822",
#                "__typename": "FloorPlan",
#                "units": [
#                     {
#                          "unitNumber": "Unit 402",
#                          "zpid": "2061645822",
#                          "__typename": "UnitV2",
#                          "housingConnector": false,
#                          "housingConnectorExclusive": false,
#                          "vrModel": null,
#                          "availableFrom": "1681714800000",
#                          "hasApprovedThirdPartyVirtualTour": false,
#                          "price": 3650,
#                          "minPrice": null,
#                          "maxPrice": null,
#                          "thirdPartyVirtualTour": null,
#                          "unitVRModel": null
#                     }
#                ],
#                "floorplanVRModel": null,
#                "minPrice": 3650,
#                "maxPrice": 3650,
#                "availableFrom": "1681714800000",
#                "baths": 2,
#                "beds": 2,
#                "floorPlanUnitPhotos": [
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/723f097df1200b85f479a4bc9344acfa-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/54e4853044c78fd0d834ab4c425c6f30-f_b.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "caption": null,
#                          "url": "https://photos.zillowstatic.com/fp/a82d5cbb530409195e65695bdf46073f-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "name": "2x2",
#                "photos": [
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/235facf0db5cdf1e54f81fc185687785-r_a.jpg",
#                          "__typename": "Photo"
#                     },
#                     {
#                          "url": "https://photos.zillowstatic.com/fp/235facf0db5cdf1e54f81fc185687785-f_b.jpg",
#                          "__typename": "Photo"
#                     }
#                ],
#                "sqft": 1005,
#                "thirdPartyVirtualTour": null,
#                "vrModels": [],
#                "maloneId": null,
#                "description": "12 months"
#           }
#      ],
#      "buildingAttributes": {
#           "hasSharedLaundry": false,
#           "airConditioning": "Unknown",
#           "appliances": [
#                "Refrigerator",
#                "Freezer",
#                "Oven",
#                "Range",
#                "MicrowaveOven",
#                "Dishwasher",
#                "GarbageDisposal",
#                "Washer",
#                "Dryer",
#                "WasherDryerHookups"
#           ],
#           "parkingTypes": [
#                "AttachedGarage",
#                "MultiLevelGarage"
#           ],
#           "detailedParkingPolicies": null,
#           "outdoorCommonAreas": [
#                "Unknown"
#           ],
#           "hasBarbecue": null,
#           "heatingSource": "Electric",
#           "detailedPetPolicy": {
#                "general": "$300 Refundable Pet Deposit. $25 Pet Rent. Breed Restrictions Apply. ESA/Service Animals OK",
#                "petPolicies": [
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": null,
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": null,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": "large",
#                          "petType": "dogs",
#                          "restriction": null
#                     },
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": null,
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": null,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": "small",
#                          "petType": "dogs",
#                          "restriction": null
#                     },
#                     {
#                          "allowed": true,
#                          "__typename": "PetPolicy",
#                          "comment": null,
#                          "deposit": 0,
#                          "description": null,
#                          "feeRangeMax": null,
#                          "feeRangeMin": null,
#                          "maxNumberAllowed": null,
#                          "maxWeightAllowed": null,
#                          "monthlyFee": null,
#                          "oneTimeFee": null,
#                          "petSize": null,
#                          "petType": "cats",
#                          "restriction": null
#                     }
#                ],
#                "__typename": "DetailedPetPolicy"
#           },
#           "petPolicies": [
#                "Cats",
#                "SmallDogs",
#                "LargeDogs"
#           ],
#           "hasElevator": true,
#           "__typename": "BuildingAttributes",
#           "communityRooms": [
#                "Unknown"
#           ],
#           "sportsCourts": [
#                "Unknown"
#           ],
#           "hasBicycleStorage": null,
#           "hasGuestSuite": null,
#           "hasStorage": null,
#           "hasPetPark": null,
#           "hasTwentyFourHourMaintenance": null,
#           "hasDryCleaningDropOff": null,
#           "hasOnlineRentPayment": true,
#           "hasOnlineMaintenancePortal": true,
#           "hasOnsiteManagement": null,
#           "hasPackageService": null,
#           "hasValetTrash": null,
#           "hasSpanishSpeakingStaff": true,
#           "securityTypes": [
#                "ControlledAccess",
#                "Intercom"
#           ],
#           "viewType": [
#                "City",
#                "Mountain",
#                "Water"
#           ],
#           "hasHotTub": null,
#           "hasSauna": null,
#           "hasSwimmingPool": null,
#           "hasAssistedLiving": false,
#           "hasDisabledAccess": null,
#           "floorCoverings": [
#                "Carpet",
#                "Laminate"
#           ],
#           "communicationTypes": [
#                "HighSpeedInternet"
#           ],
#           "hasCeilingFan": true,
#           "hasFireplace": null,
#           "hasPatioBalcony": true,
#           "isFurnished": null,
#           "customAmenities": null,
#           "parkingDescription": null,
#           "petPolicyDescription": null,
#           "parkingRentDescription": null,
#           "isSmokeFree": null,
#           "applicationFee": null,
#           "administrativeFee": null,
#           "depositFeeMin": null,
#           "depositFeeMax": null,
#           "leaseTerms": [
#                "Unknown"
#           ],
#           "utilitiesIncluded": [
#                "Unknown"
#           ],
#           "leaseLengths": null
#      },
#      "amenitySummary": {
#           "buildingDetails": null,
#           "__typename": "AmenitySummary",
#           "laundry": [
#                "Washer/dryer",
#                "washer/dryer hookups"
#           ]
#      },
#      "isLowIncome": false,
#      "isSeniorHousing": false,
#      "isStudentHousing": false,
#      "screeningCriteria": null,
#      "assignedSchools": [
#           {
#                "distance": 0.3,
#                "name": "Lowell Elementary School",
#                "rating": 8,
#                "level": "PRE_K,ELEMENTARY",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "PK-5",
#                "link": "https://www.greatschools.org/school?id=5301580&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 0.9,
#                "name": "Edmonds S. Meany Middle School",
#                "rating": 5,
#                "level": "MIDDLE",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "6-8",
#                "link": "https://www.greatschools.org/school?id=5307459&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           },
#           {
#                "distance": 1.6,
#                "name": "Garfield High School",
#                "rating": 7,
#                "level": "HIGH",
#                "studentsPerTeacher": null,
#                "assigned": null,
#                "grades": "9-12",
#                "link": "https://www.greatschools.org/school?id=5301561&state=WA",
#                "type": "PUBLIC",
#                "size": null,
#                "totalCount": null,
#                "isAssigned": true,
#                "__typename": "School"
#           }
#      ],
#      "nearbyAmenities": [],
#      "walkScore": {
#           "walkscore": 96,
#           "description": "Walker's Paradise",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.6229/lng=-122.3237/?utm_source=zillow2.com&utm_medium=ws_api&utm_campaign=ws_api",
#           "__typename": "WalkScoreResponse"
#      },
#      "transitScore": {
#           "transit_score": 80,
#           "description": "Excellent Transit",
#           "ws_link": "https://www.walkscore.com/score/loc/lat=47.6229/lng=-122.3237/?utm_source=zillow2.com&utm_medium=ts_api&utm_campaign=ts_api",
#           "__typename": "TransitScoreResponse"
#      },
#      "bikeScore": {
#           "bikescore": 84,
#           "description": "Very Bikeable",
#           "__typename": "BikeScoreResponse"
#      },
#      "description": "Ask us about our newly renovated homes! When you live at Belmont Court Apartments, you can come home with confidence. We offer spacious units here in our vibrant and upbeat neighborhood of Capitol Hill. Call today for more information on our apartments that offer views of the Seattle city skyline, the Olympic Mountains or of the Puget Sound. Our units here feature full kitchens which include a full size fridge, 4 burner stove/oven, microwave, dishwasher and washer/dryer in unit.\nBelmont Court Apartments offers studio, one bedroom, and two bedroom apartments , ranging from less expensive and affordable to luxury. When it comes to your home, you deserve the best and Belmont Court Apartments is excited to help you find your new home!",
#      "amenityDetails": {
#           "hours": [
#                "Mon - Fri: 9:00AM - 5:00PM",
#                "Sat: Closed",
#                "Sun: Closed"
#           ],
#           "__typename": "AmenityDetails",
#           "pets": [
#                "Cats",
#                "Large dogs",
#                "Small dogs"
#           ],
#           "petDetails": [],
#           "customAmenities": null,
#           "unitFeatures": [
#                "Carpet",
#                "City, mountain, water view",
#                "Dishwasher",
#                "Garbage disposal",
#                "High-speed internet ready",
#                "Laminate flooring",
#                "Microwave oven",
#                "Oven",
#                "Range",
#                "Refrigerator/freezer",
#                "Washer/dryer",
#                "Washer/dryer hookups",
#                "Ceiling fan",
#                "Patio/balcony",
#                "Heating: Electric"
#           ]
#      },
#      "detailedPetPolicy": {
#           "general": "$300 Refundable Pet Deposit. $25 Pet Rent. Breed Restrictions Apply. ESA/Service Animals OK",
#           "petPolicies": [
#                {
#                     "allowed": true,
#                     "comment": null,
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": null,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": null,
#                     "petSize": "large",
#                     "petType": "dogs",
#                     "restriction": null,
#                     "__typename": "PetPolicy"
#                },
#                {
#                     "allowed": true,
#                     "comment": null,
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": null,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": null,
#                     "petSize": "small",
#                     "petType": "dogs",
#                     "restriction": null,
#                     "__typename": "PetPolicy"
#                },
#                {
#                     "allowed": true,
#                     "comment": null,
#                     "deposit": 0,
#                     "description": null,
#                     "feeRangeMax": null,
#                     "feeRangeMin": null,
#                     "maxNumberAllowed": null,
#                     "maxWeightAllowed": null,
#                     "monthlyFee": null,
#                     "oneTimeFee": null,
#                     "petCare": null,
#                     "petSize": null,
#                     "petType": "cats",
#                     "restriction": null,
#                     "__typename": "PetPolicy"
#                }
#           ],
#           "__typename": "DetailedPetPolicy"
#      }
# }

# %%
for bld_info_dict in bld_info_list:

    # call the clean_address function
    bld_info_dict['address'] = clean_address(bld_info_dict['address'])

    # call the clean_floorPlans function
    clean_floorPlans(bld_info_dict)
    
    '''
    if key == 'buildingAttributes':
        print(value)
    if key == 'amenitySummary':
        print(value)
    if key == 'assignedSchools':
        print(value)
    if key == 'walkScore':
        print(value)
    if key == 'transitScore':
        print(value)
    if key == 'bikeScore':
        print(value)
    if key == 'amenityDetails':
        print(value)
    if key == 'detailedPetPolicy':
        print(value)
    '''
# Out:
# building address already parsed
# listing floorPlans already parsed
# building address already parsed
# listing floorPlans already parsed
# building address already parsed
# listing floorPlans already parsed
# building address already parsed
# listing floorPlans already parsed
