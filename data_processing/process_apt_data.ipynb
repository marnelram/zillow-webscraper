# %%
import json

# load the apartment dictionary
with open('C:/Projects/Housing_Price_Prediction/data_processing/raw_apt_data.json', 'r') as f:
    apt_data_str = f.read()
apt_data_list = json.loads(apt_data_str)

# %%
processed_apt_data_dict = []
for listing in apt_data_list:
    for key, value in listing.items():
        if key == 'lotId':
            processed_apt_data_dict.append({key: value})
        elif key == 'detailUrl':
            processed_apt_data_dict.append({key: value})
print(processed_apt_data_dict)
# Out:
# [{'lotId': 1008623254}, {'detailUrl': '/apartments/seattle-wa/arthouse/5Yy9f4/'}, {'detailUrl': 'https://www.zillow.com/apartments/seattle-wa/the-new-carroll/5XjRj4/'}, {'lotId': 1134781404}, {'detailUrl': '/apartments/seattle-wa/angeline-apartments/62rTfB/'}, {'lotId': 2118777852}, {'detailUrl': '/apartments/seattle-wa/axle/9VXKQL/'}, {'lotId': 1050487443}, {'detailUrl': '/apartments/seattle-wa/belmont-court-apartments/5jDzpG/'}, {'lotId': 1134733756}, {'detailUrl': '/apartments/seattle-wa/spruce/62r5pm/'}, {'lotId': 2118791304}, {'detailUrl': '/apartments/seattle-wa/mysa-apartments/9VXR2s/'}, {'lotId': 2118681664}, {'detailUrl': '/apartments/seattle-wa/augusta-apartments/9VWVMK/'}, {'lotId': 2118710863}, {'detailUrl': '/apartments/seattle-wa/artix/9VWkWD/'}, {'lotId': 2394277694}, {'detailUrl': '/b/the-kennedy-building-seattle-wa-BTL3D6/'}, {'lotId': 2087315091}, {'detailUrl': '/apartments/seattle-wa/kinects-tower/9P5tPB/'}, {'lotId': 1001549272}, {'detailUrl': '/apartments/seattle
# ...
